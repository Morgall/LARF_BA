# %% [markdown]
# Parameters for the run function is follows:
#
# - `train`: A pandas DataFrame containing the training dataset.
# - `test`: A pandas DataFrame containing the test dataset.
# - `target_label`: Target label to predict.
# - `features`: A list of features to train on.
# - `depth`: Maximum depth of the decision tree (default is 2).
# - `criterion`: Splitting criterion for the decision tree can be "misclassification" or "gini"(default is "gini").
# - `time_limit`: Time limit for training in seconds (default is 1800).
# - `big_m`: Value of big M used in the optimization model (default is 99).

# %%
import pandas as pd
import time
import os

from helpers.helpers import preprocess_numerical, move_targets_to_front_and_rename, make_data_binary

# %%
target_label = "y"
depth_rolling_tree = 8
criterion_loss = "gini"
#criterion_loss = "misclassification"


# add file savings according to loss criteria (irrelevant if we use hybrid-RST)

# %%
#organizing results in folders and txt/csv files

# test, adult, car_evaluation, seismic
dataset_name = 'seismic' # folder in 'results' will be named after it, results/dataset_name contains result .txt and .csv

dir_path = f'results/{dataset_name}/not_cval/'
file_path = f'{dir_path}/output_depth_'

# Create the directory if it doesn't exist
os.makedirs(dir_path, exist_ok=True)

# %%
if dataset_name == 'test': 

    # Load your training and test datasets
    train_data = pd.read_csv("datasets/example_datasets/train.csv")
    test_data = pd.read_csv("datasets/example_datasets/test.csv")

    with open(f'{file_path}all_{dataset_name}.txt', 'w') as f:
        f.write("Test simple dataset \n")

# %%
if dataset_name == 'adult':

    # Load your training and test datasets
    train_data = pd.read_csv("datasets/adult/adult.data", sep=',', skipinitialspace=True, header=None) #32561 rows
    test_data = pd.read_csv("datasets/adult/adult.test", sep=',', skipinitialspace=True, header=None) #16281 rows

 
    #with open(f'{file_path}all_{dataset_name}.txt', 'w') as f:
        #f.write("Test adult dataset \n")

    # Remove dots from the 'target' column
    test_data[14] = test_data[14].astype(str).str.replace('.', '', regex=False)

    len_train_data = len(train_data)

    stacked = pd.concat([train_data, test_data ], ignore_index=False)
    #print(stacked)


    stacked = preprocess_numerical(stacked)
    stacked = move_targets_to_front_and_rename(data= stacked, target_label=14)

    unique_values = stacked ['y'].unique()
    print(unique_values) # hier sieht man dann, dass es einen zusätzlichen punkt bei den target labels in adult.test gibt; also ohne löschen des punktes



    stacked = make_data_binary(stacked)
    print(stacked)




    train_data_bin = stacked.iloc[:len_train_data] #[32561 rows x 125 columns]
    test_data_bin = stacked.iloc[len_train_data:] #[16281 rows x 125 columns]

    train_data=train_data_bin
    test_data=test_data_bin

# %%
from sklearn.model_selection import train_test_split

if dataset_name == 'car_evaluation':
    # Load your training and test datasets
    data = pd.read_csv("datasets/car_evaluation/car_bin.csv")

    X = data.drop(columns=['y'])  # All columns except the target
    y = data['y']                 # Only the target column

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=100, stratify=y, random_state=42)

    stacked_train = pd.concat([y_train, X_train], axis=1, ignore_index=False)
    stacked_test = pd.concat([y_test, X_test],axis=1, ignore_index=False)
    
    train_data = stacked_train
    test_data = stacked_test

    with open(f'{file_path}all_{dataset_name}.txt', 'w') as f:
        f.write("Test simple dataset \n")

# %%
from sklearn.model_selection import train_test_split

if dataset_name == 'seismic':
    # Load your training and test datasets
    data = pd.read_csv("datasets/seismic_bumps/seismic_bin.csv")

    X = data.drop(columns=['y'])  # All columns except the target
    y = data['y']                 # Only the target column

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=100, stratify=y, random_state=42)

    stacked_train = pd.concat([y_train, X_train], axis=1, ignore_index=False)
    stacked_test = pd.concat([y_test, X_test],axis=1, ignore_index=False)
    
    train_data = stacked_train
    test_data = stacked_test

    with open(f'{file_path}all_{dataset_name}.txt', 'w') as f:
        f.write("Test simple dataset \n")

# %%
# get features
feature_columns = train_data.columns[1:] #assuming labels are in first column, ensured trough move_targets_to_front_and_rename()
#print(feature_columns)

# %% [markdown]
# # Solving with pulp

# %%
#%load_ext snakeviz

# solving with pulp

from rolling_lookahead_dt_pulp import rollo_oct_pulp

start_time_pulp = time.time()

# Run the classifier using pulp
result_dict_pulp =rollo_oct_pulp.run(train=train_data, test=test_data, target_label="y", features=feature_columns, depth=depth_rolling_tree, criterion=criterion_loss)

#cProfile.run('rollo_oct_pulp.run(train=train_data, test=test_data, target_label="y", features=feature_columns, depth=depth_rolling_tree, criterion=criterion_loss)', 'profile_rollOCT_gini.out')


# %snakeviz -t rollo_oct_pulp.run(train=train_data, test=test_data, target_label="y", features=feature_columns, depth=depth_rolling_tree, criterion=criterion_loss)
end_time_pulp = time.time()
#print(f"Pulp execution time for depth {depth_rolling_tree} : {end_time_pulp - start_time_pulp} seconds")
# Out:
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/94c34a05749b4ae5ad6aaf19ba33f755-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/94c34a05749b4ae5ad6aaf19ba33f755-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 26966 RHS
# At line 27021 BOUNDS
# At line 32430 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.112753 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.112753 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.11275308
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/e2cedcfc9f9546ffb13cede79e368f81-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/e2cedcfc9f9546ffb13cede79e368f81-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 26984 RHS
# At line 27039 BOUNDS
# At line 32448 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.0843912 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.0843912 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.08439123
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/1fe195c12f0d4569a5b730fa515a132e-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/1fe195c12f0d4569a5b730fa515a132e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 27032 RHS
# At line 27087 BOUNDS
# At line 32496 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.324048 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.324048 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.32404785
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/a82547de255c4cc89a542f05b55cad48-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/a82547de255c4cc89a542f05b55cad48-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 27028 RHS
# At line 27083 BOUNDS
# At line 32492 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.0639365 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.0639365 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.06393647
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/41a94f471d02443d9b6a4d537e155132-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/41a94f471d02443d9b6a4d537e155132-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 26938 RHS
# At line 26993 BOUNDS
# At line 32402 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.267845 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.267845 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.26784484
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/776cb2bd881f49d79ebf97261b966e85-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/776cb2bd881f49d79ebf97261b966e85-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 27051 RHS
# At line 27106 BOUNDS
# At line 32515 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.351108 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.351108 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.35110754
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/eff799da023c495e95b7e790b917b7f8-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/eff799da023c495e95b7e790b917b7f8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 27040 RHS
# At line 27095 BOUNDS
# At line 32504 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.257701 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.257701 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.25770107
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/796059d350cc4e62b3e09c171b096192-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/796059d350cc4e62b3e09c171b096192-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 27072 RHS
# At line 27127 BOUNDS
# At line 32536 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.0636554 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.0636554 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.06365538
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/f9063707d5d44f588513c3d4e53567ef-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/f9063707d5d44f588513c3d4e53567ef-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 27055 RHS
# At line 27110 BOUNDS
# At line 32519 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.282606 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.282606 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.28260554
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/cab27b9b2ad74ee0af6ab81cb3888737-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/cab27b9b2ad74ee0af6ab81cb3888737-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 26980 RHS
# At line 27035 BOUNDS
# At line 32444 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.062069 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.062069 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.06206897
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/a6e27cb21c4e486982464f5bca419d1f-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/a6e27cb21c4e486982464f5bca419d1f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 27034 RHS
# At line 27089 BOUNDS
# At line 32498 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.174545 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.174545 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.17454545
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/11781c5dc09345e99f71c5a5649a907b-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/11781c5dc09345e99f71c5a5649a907b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 27053 RHS
# At line 27108 BOUNDS
# At line 32517 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.353367 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.353367 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.35336723
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/563e3540de544afe9d3a44ba300f2d93-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/563e3540de544afe9d3a44ba300f2d93-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 27100 RHS
# At line 27155 BOUNDS
# At line 32564 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.361111 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.361111 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.36111111
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/0ea682982d514aaca68cd2cd7a9d848d-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/0ea682982d514aaca68cd2cd7a9d848d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 27044 RHS
# At line 27099 BOUNDS
# At line 32508 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.234292 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.234292 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.23429159
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/3e508480c4ff4818a2bb70456ad2e196-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/3e508480c4ff4818a2bb70456ad2e196-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 27093 RHS
# At line 27148 BOUNDS
# At line 32557 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.0874246 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.0874246 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.08742457
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/ac770024e4ed48169ba29b22356138ff-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/ac770024e4ed48169ba29b22356138ff-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 27059 RHS
# At line 27114 BOUNDS
# At line 32523 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.0322398 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.0322398 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.03223979
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/c3951ec7638549df91b2f954fadba0fe-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/c3951ec7638549df91b2f954fadba0fe-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 27079 RHS
# At line 27134 BOUNDS
# At line 32543 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.164103 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.164103 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.16410256
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/af85f13cb18148f6a36b7bcb1d6ebcf6-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/af85f13cb18148f6a36b7bcb1d6ebcf6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 27049 RHS
# At line 27104 BOUNDS
# At line 32513 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.2973 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.2973 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.29729973
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/ab3ccbbe7f2f4ca4b5630d055c644e4a-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/ab3ccbbe7f2f4ca4b5630d055c644e4a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 26959 RHS
# At line 27014 BOUNDS
# At line 32423 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.0685714 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.0685714 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.06857143
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/001a0714409e44fabd441f10d706a546-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/001a0714409e44fabd441f10d706a546-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 27061 RHS
# At line 27116 BOUNDS
# At line 32525 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.2 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.2 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.20000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/c74e9406098a433a90aa7196308c106e-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/c74e9406098a433a90aa7196308c106e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 27061 RHS
# At line 27116 BOUNDS
# At line 32525 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ...
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 27100 RHS
# At line 27155 BOUNDS
# At line 32564 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.325758 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.325758 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.32575758
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/2642b5ab28ca4404928c1ee103e7a69d-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/2642b5ab28ca4404928c1ee103e7a69d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 27100 RHS
# At line 27155 BOUNDS
# At line 32564 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 297.5 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 297.5 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                297.50000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/bc3daff82141444c88b36d399e46a76d-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/bc3daff82141444c88b36d399e46a76d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 27100 RHS
# At line 27155 BOUNDS
# At line 32564 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 297.444 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 297.444 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                297.44444444
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/7c249f9d9872474fb3795d1828e7fd66-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/7c249f9d9872474fb3795d1828e7fd66-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 27100 RHS
# At line 27155 BOUNDS
# At line 32564 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 198.3 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 198.3 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                198.30000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/b2f20ce097104e818c1b001e9264a89d-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/b2f20ce097104e818c1b001e9264a89d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 27082 RHS
# At line 27137 BOUNDS
# At line 32546 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.278711 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.278711 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.27871148
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/64e0786dbf3740f293d4516ccedf903e-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/64e0786dbf3740f293d4516ccedf903e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 27100 RHS
# At line 27155 BOUNDS
# At line 32564 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.188736 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.188736 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.18873614
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/bf02cec8f49a4deabe1fad90e7560ed1-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/bf02cec8f49a4deabe1fad90e7560ed1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 59 COLUMNS
# At line 27017 RHS
# At line 27072 BOUNDS
# At line 32481 ENDATA
# Problem MODEL has 54 rows, 5408 columns and 10816 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.0769231 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.0769231 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.07692308
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03

# %%
for depth in range(2,depth_rolling_tree+1):
    print(result_dict_pulp[depth])

print(f"Pulp execution time for depth {depth_rolling_tree} : {end_time_pulp - start_time_pulp} seconds\n")

for depth in range(2,depth_rolling_tree+1):
    with open(f'{file_path}all_{dataset_name}.txt', 'a') as f:
        f.write(str(depth) + ': ' + str(result_dict_pulp[depth]) + "\n")

with open(f'{file_path}all_{dataset_name}.txt', 'a') as f:
        f.write(f"Pulp execution time for depth {depth_rolling_tree} : {end_time_pulp - start_time_pulp} seconds\n")
# Out:
# {'training_accuracy': 0.9351851851851852, 'test_accuracy': 0.93, 'time': 1.6270301342010498}
# {'training_accuracy': 0.9355877616747182, 'test_accuracy': 0.93, 'time': 2.547801971435547}
# {'training_accuracy': 0.9380032206119162, 'test_accuracy': 0.92, 'time': 3.012683629989624}
# {'training_accuracy': 0.9404186795491143, 'test_accuracy': 0.93, 'time': 3.569056510925293}
# {'training_accuracy': 0.9412238325281803, 'test_accuracy': 0.93, 'time': 4.482797145843506}
# {'training_accuracy': 0.9424315619967794, 'test_accuracy': 0.92, 'time': 5.743795871734619}
# {'training_accuracy': 0.9456521739130435, 'test_accuracy': 0.93, 'time': 6.754490852355957}
# Pulp execution time for depth 8 : 27.743959188461304 seconds

# %%
for depth in range(2,depth_rolling_tree+1):
    with open(f'{file_path}{depth}_classification_{dataset_name}_test_pulp.csv', 'w') as f:
        f.write(str(result_dict_pulp['tree'][depth]['test'].to_csv()))
    with open(f'{file_path}{depth}_classification_{dataset_name}_train_pulp.csv', 'w') as f:
        f.write(str(result_dict_pulp['tree'][depth]['train'].to_csv()))

# %% [markdown]
# # Solving with gurobi

# %%
"""
# solving with gurobi
from rolling_lookahead_dt_gurobi import rollo_oct_gurobi

start_time_gurobi = time.time()

# Run the classifier using pulp
result_dict_gurobi, result_df_test_data_gurobi, result_df_training_data_gurobi = rollo_oct_gurobi.run(
                                                                train=train_data,
                                                                test=test_data,
                                                                target_label="y",
                                                                features=feature_columns,
                                                                depth=depth_rolling_tree,
                                                                criterion=criterion_loss
)
end_time_gurobi = time.time()
# Out:
#   Cell In[58], line 1
#     """
#     ^
# SyntaxError: incomplete input

# %%
with open(f'{file_path}_{dataset_name}.txt', 'a') as f:
    f.write(f"Gurobi execution time for depth {depth_rolling_tree} : {end_time_gurobi - start_time_gurobi} seconds\n")

print(f"Gurobi execution time for depth {depth_rolling_tree} : {end_time_gurobi - start_time_gurobi} seconds\n")
# Out:
# Gurobi execution time for depth 4 : 9.866874694824219 seconds

# %%
with open(f'{file_path}_{dataset_name}.txt', 'a') as f:
    f.write(str(result_dict_gurobi) + "\n")
print(result_dict_gurobi)
# Out:
# {3: {'training_accuracy': 0.69375, 'test_accuracy': 0.7777777777777778, 'time': 2.646049976348877}, 4: {'training_accuracy': 0.75, 'test_accuracy': 0.8333333333333334, 'time': 4.534008264541626}, 2: {'training_accuracy': 0.5875, 'test_accuracy': 0.6111111111111112, 'time': 9.863209247589111}}

# %%
with open(f'{file_path}_classification_{dataset_name}_test_gurobi.csv', 'w') as f:
    f.write(str(result_df_test_data_gurobi.to_csv()))

# %%
with open(f'{file_path}_classification_{dataset_name}_train_gurobi.csv', 'w') as f:
    f.write(str(result_df_training_data_gurobi.to_csv()))

# %% [markdown]
# # Vergleich Ergebnisse

# %%
#print(result_dict_gurobi)

# %%
#print(result_df_test_data_pulp)
# Out:
#     y  prediction  leaf
# 0   1           1    13
# 1   1           1    13
# 2   1           2    31
# 3   1           2    31
# 4   1           2    31
# 5   1           1    13
# 6   2           2    12
# 7   2           2    31
# 8   2           2    31
# 9   2           2    28
# 10  2           2    31
# 11  2           2    31
# 12  2           2    31
# 13  3           3    30
# 14  3           3     5
# 15  3           3    29
# 16  3           3     5
# 17  3           3     5

# %%
#print(result_df_test_data_gurobi)
# Out:
#     y  prediction  leaf
# 0   1           1    13
# 1   1           1    13
# 2   1           2    31
# 3   1           2    31
# 4   1           2    31
# 5   1           1    13
# 6   2           2    12
# 7   2           2    31
# 8   2           2    31
# 9   2           2    28
# 10  2           2    31
# 11  2           2    31
# 12  2           2    31
# 13  3           3    30
# 14  3           3     5
# 15  3           3    29
# 16  3           3     5
# 17  3           3     5

# %%
#print(result_df_training_data_pulp)
# Out:
#      y  prediction  leaf
# 0    1           2    31
# 1    1           2    31
# 2    1           2    31
# 3    1           1    13
# 4    1           1    13
# ..  ..         ...   ...
# 155  3           3     5
# 156  3           3     5
# 157  3           3    30
# 158  3           3    30
# 159  3           3     5
#
# [160 rows x 3 columns]

# %%
#print(result_df_training_data_gurobi)
# Out:
#      y  prediction  leaf
# 0    1           2    31
# 1    1           2    31
# 2    1           2    31
# 3    1           1    13
# 4    1           1    13
# ..  ..         ...   ...
# 155  3           3     5
# 156  3           3     5
# 157  3           3    30
# 158  3           3    30
# 159  3           3     5
#
# [160 rows x 3 columns]
