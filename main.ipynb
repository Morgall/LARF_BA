# %% [markdown]
# Parameters for the run function is follows:
#
# - `train`: A pandas DataFrame containing the training dataset.
# - `test`: A pandas DataFrame containing the test dataset.
# - `target_label`: Target label to predict.
# - `features`: A list of features to train on.
# - `depth`: Maximum depth of the decision tree (default is 2).
# - `criterion`: Splitting criterion for the decision tree can be "misclassification" or "gini"(default is "gini").
# - `time_limit`: Time limit for training in seconds (default is 1800).
# - `big_m`: Value of big M used in the optimization model (default is 99).

# %%
import pandas as pd
import time
import os

from helpers.helpers import preprocess_numerical, move_targets_to_front_and_rename, make_data_binary

# %%
target_label = "y"
depth_rolling_tree = 8
#criterion_loss = "gini"
criterion_loss = "misclassification"

# %%
#organizing results in folders and txt/csv files

dataset_name = 'adult' # folder in 'results' will be named after it, results/dataset_name contains result .txt and .csv

dir_path = f'results/{dataset_name}'
file_path = f'{dir_path}/output_depth_{depth_rolling_tree}'

# Create the directory if it doesn't exist
os.makedirs(dir_path, exist_ok=True)

# %%
if dataset_name == 'test': 

    # Load your training and test datasets
    train_data = pd.read_csv("datasets/example_datasets/train.csv")
    test_data = pd.read_csv("datasets/example_datasets/test.csv")

    with open(f'{file_path}.txt', 'w') as f:
        f.write("Test simple dataset \n")

# %%
if dataset_name == 'adult':

    # Load your training and test datasets
    train_data = pd.read_csv("datasets/adult/adult.data", sep=',', skipinitialspace=True, header=None) #32561 rows
    test_data = pd.read_csv("datasets/adult/adult.test", sep=',', skipinitialspace=True, header=None) #16281 rows

 
    with open(f'{file_path}.txt', 'w') as f:
        f.write("Test adult dataset \n")

    # Remove dots from the 'target' column
    test_data[14] = test_data[14].astype(str).str.replace('.', '', regex=False)

    len_train_data = len(train_data)

    stacked = pd.concat([train_data, test_data ], ignore_index=False)
    #print(stacked)


    stacked = preprocess_numerical(stacked)
    stacked = move_targets_to_front_and_rename(data= stacked, target_label=14)

    unique_values = stacked ['y'].unique()
    print(unique_values) # hier sieht man dann, dass es einen zusätzlichen punkt bei den target labels in adult.test gibt; also ohne löschen des punktes



    stacked = make_data_binary(stacked)
    print(stacked)




    train_data_bin = stacked.iloc[:len_train_data] #[32561 rows x 125 columns]
    test_data_bin = stacked.iloc[len_train_data:] #[16281 rows x 125 columns]

    train_data=train_data_bin
    test_data=test_data_bin

# %%
# get features
feature_columns = train_data.columns[1:] #assuming labels are in first column, ensured trough move_targets_to_front_and_rename()
#print(feature_columns)

# %% [markdown]
# # Solving with pulp

# %%
# %load_ext snakeviz

# solving with pulp

from rolling_lookahead_dt_pulp import rollo_oct_pulp

start_time_pulp = time.time()



# Run the classifier using pulp
#result_dict_pulp, result_df_test_data_pulp, result_df_training_data_pulp =

# %snakeviz -t rollo_oct_pulp.run(train=train_data, test=test_data, target_label="y", features=feature_columns, depth=depth_rolling_tree, criterion=criterion_loss)
end_time_pulp = time.time()
#print(f"Pulp execution time for depth {depth_rolling_tree} : {end_time_pulp - start_time_pulp} seconds")
# Out:
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/1eadef2da9934b86bf540be2ce582dfb-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/1eadef2da9934b86bf540be2ce582dfb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 137 COLUMNS
# At line 168144 RHS
# At line 168277 BOUNDS
# At line 202078 ENDATA
# Problem MODEL has 132 rows, 33800 columns and 67600 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.466895 - 0.01 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.466895 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.46689453
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.08
# Time (Wallclock seconds):       0.09
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.14   (Wallclock seconds):       0.17
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/b2190fa280284c7f8de1cb07d66e2b80-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/b2190fa280284c7f8de1cb07d66e2b80-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 137 COLUMNS
# At line 168129 RHS
# At line 168262 BOUNDS
# At line 202063 ENDATA
# Problem MODEL has 132 rows, 33800 columns and 67600 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.419048 - 0.01 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.419048 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.41904762
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.07
# Time (Wallclock seconds):       0.08
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.13   (Wallclock seconds):       0.15
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/f4f6aed7f8b8478da5a75547ccdc55b3-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/f4f6aed7f8b8478da5a75547ccdc55b3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 137 COLUMNS
# At line 168110 RHS
# At line 168243 BOUNDS
# At line 202044 ENDATA
# Problem MODEL has 132 rows, 33800 columns and 67600 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.399193 - 0.02 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.399193 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.39919342
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.08
# Time (Wallclock seconds):       0.09
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.14   (Wallclock seconds):       0.16
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/34b1a5c7451b48b89405c53e55092e3f-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/34b1a5c7451b48b89405c53e55092e3f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 137 COLUMNS
# At line 168242 RHS
# At line 168375 BOUNDS
# At line 202176 ENDATA
# Problem MODEL has 132 rows, 33800 columns and 67600 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.04 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.15
# Time (Wallclock seconds):       0.16
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.20   (Wallclock seconds):       0.22
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/ff53af459e8848698c6e27bf906c2485-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/ff53af459e8848698c6e27bf906c2485-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 137 COLUMNS
# At line 168025 RHS
# At line 168158 BOUNDS
# At line 201959 ENDATA
# Problem MODEL has 132 rows, 33800 columns and 67600 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.333026 - 0.01 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.333026 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.33302647
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.08
# Time (Wallclock seconds):       0.09
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.14   (Wallclock seconds):       0.16
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/692440645bf847919da6e8a3199e1f26-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/692440645bf847919da6e8a3199e1f26-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 137 COLUMNS
# At line 168035 RHS
# At line 168168 BOUNDS
# At line 201969 ENDATA
# Problem MODEL has 132 rows, 33800 columns and 67600 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.265053 - 0.01 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.265053 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.26505304
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.08
# Time (Wallclock seconds):       0.09
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.14   (Wallclock seconds):       0.16
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/30dca0c82f984a9792ca887dc973d085-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/30dca0c82f984a9792ca887dc973d085-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 137 COLUMNS
# At line 167826 RHS
# At line 167959 BOUNDS
# At line 201760 ENDATA
# Problem MODEL has 132 rows, 33800 columns and 67600 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.184921 - 0.02 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.184921 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.18492095
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.08
# Time (Wallclock seconds):       0.09
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.14   (Wallclock seconds):       0.16
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/64ec2617203e4471910dacec2509307b-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/64ec2617203e4471910dacec2509307b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 137 COLUMNS
# At line 168305 RHS
# At line 168438 BOUNDS
# At line 202239 ENDATA
# Problem MODEL has 132 rows, 33800 columns and 67600 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.04 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.16
# Time (Wallclock seconds):       0.16
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.22   (Wallclock seconds):       0.23
#
# {'leaf_nodes': [4, 5, 6, 7], 'leaf_nodes_path': {4: [1, 1], 5: [1, 0], 6: [0, 1], 7: [0, 0]}}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/1a558df426c146ebb26b8a81d21b5636-pulp.mps -sec 1800 -timeMode elapsed -branch -printingOptions all -solution /tmp/1a558df426c146ebb26b8a81d21b5636-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 137 COLUMNS
# At line 167345 RHS
# At line 167478 BOUNDS
# At line 201279 ENDATA
# Problem MODEL has 132 rows, 33800 columns and 67600 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 1800
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.116959 - 0.02 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.116959 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.11695906
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.09
# Time (Wallclock seconds):       0.10
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.15   (Wallclock seconds):       0.17
#
#
# *** Profile stats marshalled to file '/tmp/tmp8ch7q4zc'.
# Opening SnakeViz in a new tab...
# Port 8080 in use, trying another.
# snakeviz web server started on 127.0.0.1:8081; enter Ctrl-C to exit
# http://127.0.0.1:8081/snakeviz/%2Ftmp%2Ftmp8ch7q4zc

# %%
with open(f'{file_path}.txt', 'a') as f:
    f.write(f"Pulp execution time for depth {depth_rolling_tree} : {end_time_pulp - start_time_pulp} seconds\n")

print(f"Pulp execution time for depth {depth_rolling_tree} : {end_time_pulp - start_time_pulp} seconds\n")
# Out:
# Pulp execution time for depth 8 : 35.40032148361206 seconds

# %%
with open(f'{file_path}.txt', 'a') as f:
    f.write(str(result_dict_pulp) + "\n")
print(result_dict_pulp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 with open(f'{file_path}.txt', 'a') as f:
# ----> 2     f.write(str(result_dict_pulp) + "\n")
#       3 print(result_dict_pulp)
#
# NameError: name 'result_dict_pulp' is not defined

# %%
with open(f'{file_path}_classification_test_pulp.csv', 'w') as f:
    f.write(str(result_df_test_data_pulp.to_csv()))

# %%
with open(f'{file_path}_classification_train_pulp.csv', 'w') as f:
    f.write(str(result_df_training_data_pulp.to_csv()))

# %% [markdown]
# # Solving with gurobi

# %%
"""
# solving with gurobi
from rolling_lookahead_dt_gurobi import rollo_oct_gurobi

start_time_gurobi = time.time()

# Run the classifier using pulp
result_dict_gurobi, result_df_test_data_gurobi, result_df_training_data_gurobi = rollo_oct_gurobi.run(
                                                                train=train_data,
                                                                test=test_data,
                                                                target_label="y",
                                                                features=feature_columns,
                                                                depth=depth_rolling_tree,
                                                                criterion=criterion_loss
)
end_time_gurobi = time.time()
# Out:
#   Cell In[19], line 1
#     """
#     ^
# SyntaxError: incomplete input

# %%
with open(f'{file_path}.txt', 'a') as f:
    f.write(f"Gurobi execution time for depth {depth_rolling_tree} : {end_time_gurobi - start_time_gurobi} seconds\n")

print(f"Gurobi execution time for depth {depth_rolling_tree} : {end_time_gurobi - start_time_gurobi} seconds\n")
# Out:
# Gurobi execution time for depth 4 : 9.866874694824219 seconds

# %%
with open(f'{file_path}.txt', 'a') as f:
    f.write(str(result_dict_gurobi) + "\n")
print(result_dict_gurobi)
# Out:
# {3: {'training_accuracy': 0.69375, 'test_accuracy': 0.7777777777777778, 'time': 2.646049976348877}, 4: {'training_accuracy': 0.75, 'test_accuracy': 0.8333333333333334, 'time': 4.534008264541626}, 2: {'training_accuracy': 0.5875, 'test_accuracy': 0.6111111111111112, 'time': 9.863209247589111}}

# %%
with open(f'{file_path}_classification_test_gurobi.csv', 'w') as f:
    f.write(str(result_df_test_data_gurobi.to_csv()))

# %%
with open(f'{file_path}_classification_train_gurobi.csv', 'w') as f:
    f.write(str(result_df_training_data_gurobi.to_csv()))

# %% [markdown]
# # Vergleich Ergebnisse

# %%
#print(result_dict_gurobi)

# %%
print(result_df_test_data_pulp)
# Out:
#     y  prediction  leaf
# 0   1           1    13
# 1   1           1    13
# 2   1           2    31
# 3   1           2    31
# 4   1           2    31
# 5   1           1    13
# 6   2           2    12
# 7   2           2    31
# 8   2           2    31
# 9   2           2    28
# 10  2           2    31
# 11  2           2    31
# 12  2           2    31
# 13  3           3    30
# 14  3           3     5
# 15  3           3    29
# 16  3           3     5
# 17  3           3     5

# %%
print(result_df_test_data_gurobi)
# Out:
#     y  prediction  leaf
# 0   1           1    13
# 1   1           1    13
# 2   1           2    31
# 3   1           2    31
# 4   1           2    31
# 5   1           1    13
# 6   2           2    12
# 7   2           2    31
# 8   2           2    31
# 9   2           2    28
# 10  2           2    31
# 11  2           2    31
# 12  2           2    31
# 13  3           3    30
# 14  3           3     5
# 15  3           3    29
# 16  3           3     5
# 17  3           3     5

# %%
print(result_df_training_data_pulp)
# Out:
#      y  prediction  leaf
# 0    1           2    31
# 1    1           2    31
# 2    1           2    31
# 3    1           1    13
# 4    1           1    13
# ..  ..         ...   ...
# 155  3           3     5
# 156  3           3     5
# 157  3           3    30
# 158  3           3    30
# 159  3           3     5
#
# [160 rows x 3 columns]

# %%
print(result_df_training_data_gurobi)
# Out:
#      y  prediction  leaf
# 0    1           2    31
# 1    1           2    31
# 2    1           2    31
# 3    1           1    13
# 4    1           1    13
# ..  ..         ...   ...
# 155  3           3     5
# 156  3           3     5
# 157  3           3    30
# 158  3           3    30
# 159  3           3     5
#
# [160 rows x 3 columns]
