# %%
from tree_refactored.class_tree import DecisionTree_rollOCT

import numpy as np
import pandas as pd

#from sklearn.base import BaseEstimator, ClassifierMixin, clone

from scipy.stats import mode
import multiprocessing

def fit_single_tree(args):
    X, y, max_depth, max_features, random_state = args
    rng = np.random.RandomState(random_state)
    indices = np.array(X.index)
    sample_indices = rng.choice(indices, size=len(indices), replace=True)
    #sample_indices = rng.choice(indices, size=int(np.sqrt(len(indices))), replace=False) # Picks len(indices) samples with replacement => means some rows will repeat, others will be omitted → those omitted are "out-of-bag" (OOB)
    oob_mask = ~np.isin(indices, sample_indices)
    oob_indices = indices[oob_mask]

    X_boot = X.loc[sample_indices]
    y_boot = y.loc[sample_indices]
    train_data = pd.concat([y_boot, X_boot], axis=1)
    train_data.columns = ['y'] + list(range(X.shape[1]))

    if len(oob_indices) > 0:
        X_oob = X.loc[oob_indices]
        y_oob = y.loc[oob_indices]
        test_data = pd.concat([y_oob, X_oob], axis=1)
        test_data.columns = ['y'] + list(range(X.shape[1]))
    else:
        test_data = train_data.copy()

    tree = DecisionTree_rollOCT(max_depth=max_depth, max_features = max_features)
    tree.fit(X_boot, y_boot)
    return tree, (sample_indices, oob_indices)


class CustomForestClassifier:
    def __init__(self, n_estimators=10, random_state=None, cores_to_use = 1, max_depth=8, max_features=None):
        """
        n_estimators: number of trees in the ensemble
        tree_kwargs: dictionary of keyword args for CustomTreeWrapper (except train_data and test_data)
        random_state: seed for reproducible bootstrap sampling
        """
        self.n_estimators = n_estimators
        self.max_depth = max_depth          #max depth of a tree
        self.max_features = max_features    #features used in each split in tree
        #self.tree_kwargs = tree_kwargs if tree_kwargs is not None else {}
        self.random_state = random_state
        self.trees_ = []
        self.bootstrap_indices_ = []
        self.cores_to_use = cores_to_use

    def fit(self, X, y): # uses parallel fit directly
        #num_cores_to_use = 6
        pool = multiprocessing.Pool(processes=self.cores_to_use)
        random_states = [self.random_state + i for i in range(self.n_estimators)] if self.random_state is not None else [None]*self.n_estimators
        args = [(X, y, self.max_depth,self.max_features , rs) for rs in random_states]

        results = pool.map(fit_single_tree, args)
        pool.close()
        pool.join()

        self.trees_ = [res[0] for res in results] #rebuilds the classifier’s internal list of trained trees from the results returned by pool.map()
        self.bootstrap_indices_ = [res[1] for res in results]
        return self
  

    def predict(self, X):
        """
        Majority-vote ensemble prediction.
        Returns: pd.Series with predictions, aligned to X.index
        """
        # Aggregate predictions (each as Series aligned to X.index)
        all_preds = pd.DataFrame()
        for tree in self.trees_:
            pred = tree.predict(X)
            pred  = pred.astype(int)
            all_preds = pd.concat([all_preds, pred], axis=1)
        # row-wise majority vote (handle multiple modes by picking first)
        maj_vote = all_preds.mode(axis=1)[0]
        maj_vote.index = X.index  # ensure correct alignment
        maj_vote = maj_vote.astype(int)
        return maj_vote

    def predict_proba(self, X):
        """
        For binary classification:
        Returns an array of shape (n_samples, 2)
        """
        all_preds = []
        for tree in self.trees_:
            pred = tree.predict(X)
            if not isinstance(pred, pd.Series):
                pred = pd.Series(pred, index=X.index)
            all_preds.append(pred)
        preds_matrix = pd.concat(all_preds, axis=1)

        # Works for binary or multiclass
        classes_ = np.unique(preds_matrix.values)
        proba = np.zeros((X.shape[0], len(classes_)))
        for i, c in enumerate(classes_):
            proba[:, i] = (preds_matrix == c).sum(axis=1) / self.n_estimators
        return proba

    def oob_score(self, X, y):
        """
        Returns out-of-bag score.
        """
        # Prepare OOB predictions
        oob_votes = {idx: [] for idx in X.index}
        for (sample_ind, oob_ind), tree in zip(self.bootstrap_indices_, self.trees_):
            if len(oob_ind) == 0:
                continue
            X_oob = X.loc[oob_ind]
            preds = tree.predict(X_oob)
            for idx, pred in preds.items():
                oob_votes[idx].append(pred)
        # Only score samples with at least one OOB prediction
        final_oob_preds = []
        final_oob_true = []
        for idx, votes in oob_votes.items():
            if votes:
                final_oob_preds.append(mode(votes)[0][0])
                final_oob_true.append(y.loc[idx])
        if not final_oob_preds:
            raise ValueError("No OOB predictions collected.")
        accuracy = np.mean(np.array(final_oob_preds) == np.array(final_oob_true))
        return accuracy

# %%
#data_seismic = pd.read_csv("datasets/seismic/seismic_bin.csv")
data_test = pd.read_csv("datasets/example_datasets/stacked.csv")
data_spambase = pd.read_csv("datasets/spambase/spambase_bin.csv")
data_nursery = pd.read_csv("datasets/nursery/nursery_bin.csv")
data_adult = pd.read_csv("datasets/adult/stacked.csv")
data_monk2 = pd.read_csv("datasets/monk2/monk2_bin.csv")

data = data_monk2

# %%
from sklearn.model_selection import StratifiedKFold

skf = StratifiedKFold(n_splits=2, shuffle=True, random_state=42)
tree_kwargs = dict(depth=8)

features = data.drop(columns=['y'])
targets = data['y']

for train_idx, test_idx in skf.split(features, targets): #gives row indices
    
    
    features_train = features.iloc[train_idx]
    features_test = features.iloc[test_idx]
    targets_train = targets.iloc[train_idx]
    targets_test = targets.iloc[test_idx]

    forest = CustomForestClassifier(n_estimators=20, random_state=42, cores_to_use=1, max_depth=8, max_features='sqrt')

# %%
forest.fit(features_train, targets_train)
# Out:
# Training each tree split on 3 features of all 15 features
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 0 with depth 0
# Subset features rows 301
# targets rows 301
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 10
# No (0) instance child feature: 15
# Yes (1) instance child feature: 14
# new depth of tree 2
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 1 with depth 1
# Subset features rows 197
# targets rows 197
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 2
# No (0) instance child feature: 15
# Yes (1) instance child feature: 15
# new depth of tree 3
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 2 with depth 1
# Subset features rows 104
# targets rows 104
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 3
# No (0) instance child feature: 8
# Yes (1) instance child feature: 8
# new depth of tree 3
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 3 with depth 2
# Subset features rows 97
# targets rows 97
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 7
# No (0) instance child feature: 5
# Yes (1) instance child feature: 6
# new depth of tree 4
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 4 with depth 2
# Subset features rows 100
# targets rows 100
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 9
# No (0) instance child feature: 8
# Yes (1) instance child feature: 8
# new depth of tree 4
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 5 with depth 2
# Subset features rows 68
# targets rows 68
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 5
# No (0) instance child feature: 8
# Yes (1) instance child feature: 8
# new depth of tree 4
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 6 with depth 2
# Subset features rows 36
# targets rows 36
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 9
# No (0) instance child feature: 1
# Yes (1) instance child feature: 1
# new depth of tree 4
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 7 with depth 3
# Subset features rows 70
# targets rows 70
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 9
# No (0) instance child feature: 14
# Yes (1) instance child feature: 14
# new depth of tree 5
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 8 with depth 3
# Subset features rows 27
# targets rows 27
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 1
# No (0) instance child feature: 11
# Yes (1) instance child feature: 11
# new depth of tree 5
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 9 with depth 3
# Subset features rows 57
# targets rows 57
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 2
# No (0) instance child feature: 12
# Yes (1) instance child feature: 9
# new depth of tree 5
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 10 with depth 3
# Subset features rows 43
# targets rows 43
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 4
# No (0) instance child feature: 6
# Yes (1) instance child feature: 3
# new depth of tree 5
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 11 with depth 3
# Subset features rows 36
# targets rows 36
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 8
# No (0) instance child feature: 14
# Yes (1) instance child feature: 15
# new depth of tree 5
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 12 with depth 3
# Subset features rows 32
# targets rows 32
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 8
# No (0) instance child feature: 14
# Yes (1) instance child feature: 14
# new depth of tree 5
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 13 with depth 3
# Subset features rows 36
# targets rows 36
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 7
# No (0) instance child feature: 6
# Yes (1) instance child feature: 6
# new depth of tree 5
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 15 with depth 4
# Subset features rows 28
# targets rows 28
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 12
# No (0) instance child feature: 2
# Yes (1) instance child feature: 2
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 16 with depth 4
# Subset features rows 42
# targets rows 42
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 13
# No (0) instance child feature: 1
# Yes (1) instance child feature: 1
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 17 with depth 4
# Subset features rows 12
# targets rows 12
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 2
# No (0) instance child feature: 7
# Yes (1) instance child feature: 9
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 18 with depth 4
# Subset features rows 15
# targets rows 15
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 1
# No (0) instance child feature: 3
# Yes (1) instance child feature: 2
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 20 with depth 4
# Subset features rows 57
# targets rows 57
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 1
# No (0) instance child feature: 3
# Yes (1) instance child feature: 7
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 21 with depth 4
# Subset features rows 26
# targets rows 26
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 6
# No (0) instance child feature: 13
# Yes (1) instance child feature: 15
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 22 with depth 4
# Subset features rows 17
# targets rows 17
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 2
# No (0) instance child feature: 6
# Yes (1) instance child feature: 6
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 23 with depth 4
# Subset features rows 20
# targets rows 20
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 7
# No (0) instance child feature: 13
# Yes (1) instance child feature: 13
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 24 with depth 4
# Subset features rows 16
# targets rows 16
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 8
# No (0) instance child feature: 15
# Yes (1) instance child feature: 9
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 25 with depth 4
# Subset features rows 16
# targets rows 16
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 13
# No (0) instance child feature: 5
# Yes (1) instance child feature: 5
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 26 with depth 4
# Subset features rows 16
# targets rows 16
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 7
# No (0) instance child feature: 5
# Yes (1) instance child feature: 5
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 27 with depth 4
# Subset features rows 20
# targets rows 20
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 2
# No (0) instance child feature: 14
# Yes (1) instance child feature: 13
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 28 with depth 4
# Subset features rows 16
# targets rows 16
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 3
# No (0) instance child feature: 13
# Yes (1) instance child feature: 5
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 31 with depth 5
# Subset features rows 19
# targets rows 19
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 8
# No (0) instance child feature: 3
# Yes (1) instance child feature: 3
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 32 with depth 5
# Subset features rows 9
# targets rows 9
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 14
# No (0) instance child feature: 9
# Yes (1) instance child feature: 9
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 33 with depth 5
# Subset features rows 34
# targets rows 34
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 7
# No (0) instance child feature: 3
# Yes (1) instance child feature: 3
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 34 with depth 5
# Subset features rows 8
# targets rows 8
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 3
# No (0) instance child feature: 13
# Yes (1) instance child feature: 13
#
# Distributing to children from pure node 70...
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 35 with depth 5
# Subset features rows 12
# targets rows 12
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 3
# No (0) instance child feature: 9
# Yes (1) instance child feature: 9
#
# Distributing to children from pure node 72...
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 38 with depth 5
# Subset features rows 15
# targets rows 15
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 14
# No (0) instance child feature: 7
# Yes (1) instance child feature: 7
#
# Distributing to children from pure node 78...
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 41 with depth 5
# Subset features rows 22
# targets rows 22
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 4
# No (0) instance child feature: 3
# Yes (1) instance child feature: 3
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 42 with depth 5
# Subset features rows 35
# targets rows 35
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 8
# No (0) instance child feature: 3
# Yes (1) instance child feature: 3
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 43 with depth 5
# Subset features rows 18
# targets rows 18
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 7
# No (0) instance child feature: 15
# Yes (1) instance child feature: 14
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 44 with depth 5
# Subset features rows 8
# targets rows 8
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 8
# No (0) instance child feature: 2
# Yes (1) instance child feature: 2
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 46 with depth 5
# Subset features rows 17
# targets rows 17
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 5
# No (0) instance child feature: 7
# Yes (1) instance child feature: 7
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 47 with depth 5
# Subset features rows 11
# targets rows 11
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 13
# No (0) instance child feature: 1
# Yes (1) instance child feature: 1
#
# Distributing to children from pure node 96...
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 48 with depth 5
# Subset features rows 9
# targets rows 9
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 2
# No (0) instance child feature: 15
# Yes (1) instance child feature: 14
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 50 with depth 5
# Subset features rows 16
# targets rows 16
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 1
# No (0) instance child feature: 6
# Yes (1) instance child feature: 13
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 51 with depth 5
# Subset features rows 11
# targets rows 11
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 13
# No (0) instance child feature: 3
# Yes (1) instance child feature: 3
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 52 with depth 5
# Subset features rows 5
# targets rows 5
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 2
# No (0) instance child feature: 1
# Yes (1) instance child feature: 1
#
# Distributing to children from pure node 105...
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 53 with depth 5
# Subset features rows 16
# targets rows 16
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 11
# No (0) instance child feature: 1
# Yes (1) instance child feature: 1
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 55 with depth 5
# Subset features rows 8
# targets rows 8
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 7
# No (0) instance child feature: 11
# Yes (1) instance child feature: 13
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 56 with depth 5
# Subset features rows 12
# targets rows 12
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 6
# No (0) instance child feature: 5
# Yes (1) instance child feature: 13
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 58 with depth 5
# Subset features rows 16
# targets rows 16
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 13
# No (0) instance child feature: 9
# Yes (1) instance child feature: 15
#
# Distributing to children from pure node 118...
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 63 with depth 6
# Subset features rows 6
# targets rows 6
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 11
# No (0) instance child feature: 6
# Yes (1) instance child feature: 6
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 64 with depth 6
# Subset features rows 13
# targets rows 13
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 1
# No (0) instance child feature: 15
# Yes (1) instance child feature: 15
#
# Distributing to children from pure node 129...
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 65 with depth 6
# Subset features rows 9
# targets rows 9
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 1
# No (0) instance child feature: 4
# Yes (1) instance child feature: 4
#
# Distributing to children from pure node 131...
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 67 with depth 6
# Subset features rows 34
# targets rows 34
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 3
# No (0) instance child feature: 14
# Yes (1) instance child feature: 14
#
# Distributing to children from pure node 136...
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 69 with depth 6
# Subset features rows 6
# targets rows 6
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 8
# No (0) instance child feature: 5
# Yes (1) instance child feature: 1
#
# Distributing to children from pure node 139...
#
# Distributing to children from pure node 140...
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 77 with depth 6
# Subset features rows 12
# targets rows 12
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 6
# No (0) instance child feature: 9
# Yes (1) instance child feature: 9
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 83 with depth 6
# Subset features rows 11
# targets rows 11
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 3
# No (0) instance child feature: 12
# Yes (1) instance child feature: 12
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 84 with depth 6
# Subset features rows 11
# targets rows 11
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 11
# No (0) instance child feature: 2
# Yes (1) instance child feature: 2
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 85 with depth 6
# Subset features rows 24
# targets rows 24
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 15
# No (0) instance child feature: 2
# Yes (1) instance child feature: 2
#
# Distributing to children from pure node 172...
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 87 with depth 6
# Subset features rows 7
# targets rows 7
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 3
# No (0) instance child feature: 2
# Yes (1) instance child feature: 2
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 88 with depth 6
# Subset features rows 11
# targets rows 11
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 15
# No (0) instance child feature: 11
# Yes (1) instance child feature: 14
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 89 with depth 6
# Subset features rows 8
# targets rows 8
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 5
# No (0) instance child feature: 15
# Yes (1) instance child feature: 15
#
# Distributing to children from pure node 179...
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 93 with depth 6
# Subset features rows 17
# targets rows 17
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 6
# No (0) instance child feature: 13
# Yes (1) instance child feature: 13
#
# Distributing to children from pure node 188...
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 95 with depth 6
# Subset features rows 10
# targets rows 10
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 7
# No (0) instance child feature: 2
# Yes (1) instance child feature: 2
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 97 with depth 6
# Subset features rows 4
# targets rows 4
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 12
# No (0) instance child feature: 1
# Yes (1) instance child feature: 1
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 98 with depth 6
# Subset features rows 5
# targets rows 5
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 1
# No (0) instance child feature: 13
# Yes (1) instance child feature: 3
#
# Distributing to children from pure node 198...
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 101 with depth 6
# Subset features rows 11
# targets rows 11
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 2
# No (0) instance child feature: 11
# Yes (1) instance child feature: 13
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 102 with depth 6
# Subset features rows 5
# targets rows 5
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 7
# No (0) instance child feature: 5
# Yes (1) instance child feature: 5
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 103 with depth 6
# Subset features rows 11
# targets rows 11
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 7
# No (0) instance child feature: 4
# Yes (1) instance child feature: 4
#
# Distributing to children from pure node 208...
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 106 with depth 6
# Subset features rows 4
# targets rows 4
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 13
# No (0) instance child feature: 6
# Yes (1) instance child feature: 2
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 107 with depth 6
# Subset features rows 16
# targets rows 16
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 12
# No (0) instance child feature: 3
# Yes (1) instance child feature: 14
#
# Distributing to children from pure node 216...
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 111 with depth 6
# Subset features rows 8
# targets rows 8
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 14
# No (0) instance child feature: 4
# Yes (1) instance child feature: 4
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 113 with depth 6
# Subset features rows 10
# targets rows 10
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 14
# No (0) instance child feature: 2
# Yes (1) instance child feature: 2
#
# Distributing to children from pure node 228...
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 114 with depth 6
# Subset features rows 2
# targets rows 2
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 4
# No (0) instance child feature: 11
# Yes (1) instance child feature: 12
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 117 with depth 6
# Subset features rows 14
# targets rows 14
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 8
# No (0) instance child feature: 13
# Yes (1) instance child feature: 14
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 128 with depth 7
#
#  tree getting to deep ... stopping the building
# Training each tree split on 3 features of all 15 features
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 0 with depth 0
# Subset features rows 301
# targets rows 301
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 4
# No (0) instance child feature: 1
# Yes (1) instance child feature: 13
# new depth of tree 2
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 1 with depth 1
# Subset features rows 187
# targets rows 187
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 6
# No (0) instance child feature: 11
# Yes (1) instance child feature: 9
# new depth of tree 3
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 2 with depth 1
# Subset features rows 114
# targets rows 114
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 9
# No (0) instance child feature: 1
# Yes (1) instance child feature: 1
# new depth of tree 3
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 3 with depth 2
# Subset features rows 121
# targets rows 121
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 5
# No (0) instance child feature: 1
# Yes (1) instance child feature: 1
# new depth of tree 4
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 4 with depth 2
# Subset features rows 66
# targets rows 66
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 11
# No (0) instance child feature: 12
# Yes (1) instance child feature: 12
# new depth of tree 4
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 5 with depth 2
# Subset features rows 78
# targets rows 78
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 4
# No (0) instance child feature: 12
# Yes (1) instance child feature: 9
# new depth of tree 4
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 6 with depth 2
# Subset features rows 36
# targets rows 36
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 15
# No (0) instance child feature: 12
# Yes (1) instance child feature: 12
#
# Distributing to children from pure node 14...
# new depth of tree 4
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 7 with depth 3
# Subset features rows 54
# targets rows 54
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 9
# No (0) instance child feature: 14
# Yes (1) instance child feature: 14
# new depth of tree 5
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 8 with depth 3
# Subset features rows 67
# targets rows 67
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 12
# No (0) instance child feature: 9
# Yes (1) instance child feature: 9
# new depth of tree 5
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 9 with depth 3
# Subset features rows 45
# targets rows 45
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 2
# No (0) instance child feature: 13
# Yes (1) instance child feature: 13
# new depth of tree 5
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 10 with depth 3
# Subset features rows 21
# targets rows 21
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 2
# No (0) instance child feature: 1
# Yes (1) instance child feature: 1
# new depth of tree 5
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 12 with depth 3
# Subset features rows 78
# targets rows 78
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 2
# No (0) instance child feature: 10
# Yes (1) instance child feature: 10
# new depth of tree 5
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 13 with depth 3
# Subset features rows 29
# targets rows 29
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 14
# No (0) instance child feature: 4
# Yes (1) instance child feature: 4
# new depth of tree 5
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 15 with depth 4
# Subset features rows 30
# targets rows 30
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 15
# No (0) instance child feature: 3
# Yes (1) instance child feature: 3
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 16 with depth 4
# Subset features rows 24
# targets rows 24
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 7
# No (0) instance child feature: 13
# Yes (1) instance child feature: 13
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 17 with depth 4
# Subset features rows 53
# targets rows 53
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 7
# No (0) instance child feature: 14
# Yes (1) instance child feature: 14
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 18 with depth 4
# Subset features rows 14
# targets rows 14
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 12
# No (0) instance child feature: 3
# Yes (1) instance child feature: 3
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 19 with depth 4
# Subset features rows 23
# targets rows 23
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 15
# No (0) instance child feature: 6
# Yes (1) instance child feature: 6
#
# Distributing to children from pure node 40...
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 20 with depth 4
# Subset features rows 22
# targets rows 22
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 3
# No (0) instance child feature: 9
# Yes (1) instance child feature: 9
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 21 with depth 4
# Subset features rows 6
# targets rows 6
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 13
# No (0) instance child feature: 6
# Yes (1) instance child feature: 6
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 22 with depth 4
# Subset features rows 15
# targets rows 15
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 12
# No (0) instance child feature: 10
# Yes (1) instance child feature: 15
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 25 with depth 4
# Subset features rows 35
# targets rows 35
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 8
# No (0) instance child feature: 4
# Yes (1) instance child feature: 7
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 26 with depth 4
# Subset features rows 43
# targets rows 43
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 10
# No (0) instance child feature: 12
# Yes (1) instance child feature: 12
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 27 with depth 4
# Subset features rows 17
# targets rows 17
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 4
# No (0) instance child feature: 12
# Yes (1) instance child feature: 9
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 28 with depth 4
# Subset features rows 12
# targets rows 12
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 8
# No (0) instance child feature: 2
# Yes (1) instance child feature: 2
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 31 with depth 5
# Subset features rows 27
# targets rows 27
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 7
# No (0) instance child feature: 11
# Yes (1) instance child feature: 11
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 32 with depth 5
# Subset features rows 3
# targets rows 3
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 6
# No (0) instance child feature: 2
# Yes (1) instance child feature: 2
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 33 with depth 5
# Subset features rows 8
# targets rows 8
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 15
# No (0) instance child feature: 5
# Yes (1) instance child feature: 5
#
# Distributing to children from pure node 68...
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 34 with depth 5
# Subset features rows 16
# targets rows 16
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 14
# No (0) instance child feature: 7
# Yes (1) instance child feature: 7
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 35 with depth 5
# Subset features rows 23
# targets rows 23
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 13
# No (0) instance child feature: 5
# Yes (1) instance child feature: 5
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 36 with depth 5
# Subset features rows 30
# targets rows 30
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 9
# No (0) instance child feature: 2
# Yes (1) instance child feature: 1
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 38 with depth 5
# Subset features rows 14
# targets rows 14
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 1
# No (0) instance child feature: 9
# Yes (1) instance child feature: 9
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 39 with depth 5
# Subset features rows 10
# targets rows 10
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 15
# No (0) instance child feature: 5
# Yes (1) instance child feature: 5
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 41 with depth 5
# Subset features rows 12
# targets rows 12
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 1
# No (0) instance child feature: 4
# Yes (1) instance child feature: 4
#
# Distributing to children from pure node 83...
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 42 with depth 5
# Subset features rows 10
# targets rows 10
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 9
# No (0) instance child feature: 13
# Yes (1) instance child feature: 7
#
# Distributing to children from pure node 86...
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 44 with depth 5
# Subset features rows 6
# targets rows 6
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 5
# No (0) instance child feature: 3
# Yes (1) instance child feature: 3
#
# Distributing to children from pure node 89...
#
# Distributing to children from pure node 90...
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 45 with depth 5
# Subset features rows 10
# targets rows 10
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 14
# No (0) instance child feature: 9
# Yes (1) instance child feature: 9
#
# Distributing to children from pure node 92...
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 46 with depth 5
# Subset features rows 5
# targets rows 5
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 7
# No (0) instance child feature: 3
# Yes (1) instance child feature: 3
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 51 with depth 5
# Subset features rows 26
# targets rows 26
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 1
# No (0) instance child feature: 14
# Yes (1) instance child feature: 14
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 52 with depth 5
# Subset features rows 9
# targets rows 9
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 11
# No (0) instance child feature: 15
# Yes (1) instance child feature: 15
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 53 with depth 5
# Subset features rows 23
# targets rows 23
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 9
# No (0) instance child feature: 6
# Yes (1) instance child feature: 6
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 54 with depth 5
# Subset features rows 20
# targets rows 20
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 12
# No (0) instance child feature: 2
# Yes (1) instance child feature: 2
#
# Distributing to children from pure node 110...
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 56 with depth 5
# Subset features rows 17
# targets rows 17
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 8
# No (0) instance child feature: 9
# Yes (1) instance child feature: 9
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 57 with depth 5
# Subset features rows 6
# targets rows 6
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 14
# No (0) instance child feature: 7
# Yes (1) instance child feature: 7
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 58 with depth 5
# Subset features rows 6
# targets rows 6
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 14
# No (0) instance child feature: 9
# Yes (1) instance child feature: 9
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 63 with depth 6
# Subset features rows 14
# targets rows 14
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 1
# No (0) instance child feature: 14
# Yes (1) instance child feature: 13
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 64 with depth 6
# Subset features rows 13
# targets rows 13
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 11
# No (0) instance child feature: 14
# Yes (1) instance child feature: 14
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 67 with depth 6
# Subset features rows 6
# targets rows 6
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 14
# No (0) instance child feature: 4
# Yes (1) instance child feature: 12
#
# Distributing to children from pure node 135...
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 69 with depth 6
# Subset features rows 13
# targets rows 13
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 6
# No (0) instance child feature: 3
# Yes (1) instance child feature: 3
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 70 with depth 6
# Subset features rows 3
# targets rows 3
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 12
# No (0) instance child feature: 8
# Yes (1) instance child feature: 8
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 71 with depth 6
# Subset features rows 14
# targets rows 14
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 7
# No (0) instance child feature: 2
# Yes (1) instance child feature: 2
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 72 with depth 6
# Subset features rows 9
# targets rows 9
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 15
# No (0) instance child feature: 5
# Yes (1) instance child feature: 5
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 73 with depth 6
# Subset features rows 20
# targets rows 20
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 11
# No (0) instance child feature: 5
# Yes (1) instance child feature: 5
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 74 with depth 6
# Subset features rows 10
# targets rows 10
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 10
# No (0) instance child feature: 11
# Yes (1) instance child feature: 13
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 78 with depth 6
# Subset features rows 10
# targets rows 10
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 15
# No (0) instance child feature: 3
# Yes (1) instance child feature: 3
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 79 with depth 6
# Subset features rows 10
# targets rows 10
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 5
# No (0) instance child feature: 9
# Yes (1) instance child feature: 6
#
# Distributing to children from pure node 159...
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 84 with depth 6
# Subset features rows 7
# targets rows 7
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 14
# No (0) instance child feature: 2
# Yes (1) instance child feature: 2
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 85 with depth 6
# Subset features rows 4
# targets rows 4
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 12
# No (0) instance child feature: 8
# Yes (1) instance child feature: 8
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 91 with depth 6
# Subset features rows 9
# targets rows 9
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 12
# No (0) instance child feature: 10
# Yes (1) instance child feature: 10
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 93 with depth 6
# Subset features rows 5
# targets rows 5
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 14
# No (0) instance child feature: 12
# Yes (1) instance child feature: 12
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 103 with depth 6
# Subset features rows 10
# targets rows 10
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 5
# No (0) instance child feature: 1
# Yes (1) instance child feature: 1
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 104 with depth 6
# Subset features rows 16
# targets rows 16
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 3
# No (0) instance child feature: 10
# Yes (1) instance child feature: 11
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 105 with depth 6
# Subset features rows 3
# targets rows 3
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 1
# No (0) instance child feature: 7
# Yes (1) instance child feature: 7
#
# Distributing to children from pure node 212...
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 106 with depth 6
# Subset features rows 6
# targets rows 6
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 8
# No (0) instance child feature: 5
# Yes (1) instance child feature: 5
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 107 with depth 6
# Subset features rows 23
# targets rows 23
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 14
# No (0) instance child feature: 10
# Yes (1) instance child feature: 15
#
# Distributing to children from pure node 216...
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 109 with depth 6
# Subset features rows 15
# targets rows 15
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 6
# No (0) instance child feature: 3
# Yes (1) instance child feature: 13
#
# Distributing to children from pure node 219...
#
# Distributing to children from pure node 220...
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 113 with depth 6
# Subset features rows 11
# targets rows 11
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 12
# No (0) instance child feature: 9
# Yes (1) instance child feature: 9
#
# Distributing to children from pure node 228...
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 114 with depth 6
# Subset features rows 6
# targets rows 6
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 5
# No (0) instance child feature: 12
# Yes (1) instance child feature: 13
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 118 with depth 6
# Subset features rows 6
# targets rows 6
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 2
# No (0) instance child feature: 14
# Yes (1) instance child feature: 14
#
# Distributing to children from pure node 35...
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 18 with depth 4
# Subset features rows 12
# targets rows 12
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 10
# No (0) instance child feature: 5
# Yes (1) instance child feature: 5
#
# Distributing to children from pure node 38...
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 19 with depth 4
# Subset features rows 61
# targets rows 61
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 15
# No (0) instance child feature: 8
# Yes (1) instance child feature: 11
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 20 with depth 4
# Subset features rows 29
# targets rows 29
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 2
# No (0) instance child feature: 12
# Yes (1) instance child feature: 12
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 21 with depth 4
# Subset features rows 31
# targets rows 31
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 10
# No (0) instance child feature: 12
# Yes (1) instance child feature: 12
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 22 with depth 4
# Subset features rows 12
# targets rows 12
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 10
# No (0) instance child feature: 3
# Yes (1) instance child feature: 3
#
# Distributing to children from pure node 46...
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 23 with depth 4
# Subset features rows 10
# targets rows 10
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 5
# No (0) instance child feature: 10
# Yes (1) instance child feature: 10
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 24 with depth 4
# Subset features rows 14
# targets rows 14
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 1
# No (0) instance child feature: 11
# Yes (1) instance child feature: 2
#
# Distributing to children from pure node 49...
#
# Distributing to children from pure node 50...
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 25 with depth 4
# Subset features rows 7
# targets rows 7
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 12
# No (0) instance child feature: 2
# Yes (1) instance child feature: 8
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 27 with depth 4
# Subset features rows 11
# targets rows 11
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 4
# No (0) instance child feature: 7
# Yes (1) instance child feature: 7
#
# Distributing to children from pure node 55...
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 28 with depth 4
# Subset features rows 19
# targets rows 19
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 8
# No (0) instance child feature: 4
# Yes (1) instance child feature: 4
#
# Distributing to children from pure node 58...
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 31 with depth 5
# Subset features rows 33
# targets rows 33
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 3
# No (0) instance child feature: 11
# Yes (1) instance child feature: 11
#
# Distributing to children from pure node 64...
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 32 with depth 5
# Subset features rows 7
# targets rows 7
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 2
# No (0) instance child feature: 14
# Yes (1) instance child feature: 3
#
# Distributing to children from pure node 66...
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 33 with depth 5
# Subset features rows 9
# targets rows 9
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 9
# No (0) instance child feature: 3
# Yes (1) instance child feature: 3
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 34 with depth 5
# Subset features rows 9
# targets rows 9
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 10
# No (0) instance child feature: 5
# Yes (1) instance child feature: 5
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 37 with depth 5
# Subset features rows 8
# targets rows 8
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 15
# No (0) instance child feature: 7
# Yes (1) instance child feature: 9
#
# Distributing to children from pure node 76...
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 39 with depth 5
# Subset features rows 35
# targets rows 35
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 3
# No (0) instance child feature: 11
# Yes (1) instance child feature: 11
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 40 with depth 5
# Subset features rows 26
# targets rows 26
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 3
# No (0) instance child feature: 10
# Yes (1) instance child feature: 10
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 41 with depth 5
# Subset features rows 9
# targets rows 9
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 2
# No (0) instance child feature: 4
# Yes (1) instance child feature: 11
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 42 with depth 5
# Subset features rows 20
# targets rows 20
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 7
# No (0) instance child feature: 11
# Yes (1) instance child feature: 10
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 43 with depth 5
# Subset features rows 25
# targets rows 25
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 2
# No (0) instance child feature: 12
# Yes (1) instance child feature: 12
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 44 with depth 5
# Subset features rows 6
# targets rows 6
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 10
# No (0) instance child feature: 6
# Yes (1) instance child feature: 6
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 45 with depth 5
# Subset features rows 10
# targets rows 10
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 2
# No (0) instance child feature: 9
# Yes (1) instance child feature: 9
#
# Distributing to children from pure node 92...
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 47 with depth 5
# Subset features rows 5
# targets rows 5
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 9
# No (0) instance child feature: 11
# Yes (1) instance child feature: 11
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 48 with depth 5
# Subset features rows 5
# targets rows 5
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 13
# No (0) instance child feature: 3
# Yes (1) instance child feature: 3
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 51 with depth 5
# Subset features rows 7
# targets rows 7
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 8
# No (0) instance child feature: 1
# Yes (1) instance child feature: 7
#
# Distributing to children from pure node 103...
#
# Distributing to children from pure node 104...
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 57 with depth 5
# Subset features rows 16
# targets rows 16
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 3
# No (0) instance child feature: 2
# Yes (1) instance child feature: 2
#
# Distributing to children from pure node 116...
# new depth of tree 7
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 63 with depth 6
# Subset features rows 24
# targets rows 24
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 7
# No (0) instance child feature: 8
# Yes (1) instance child feature: 8
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 65 with depth 6
# Subset features rows 3
# targets rows 3
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 10
# No (0) instance child feature: 4
# Yes (1) instance child feature: 4
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 67 with depth 6
# Subset features rows 9
# targets rows 9
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 14
# No (0) instance child feature: 6
# Yes (1) instance child feature: 6
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 69 with depth 6
# Subset features rows 9
# targets rows 9
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 4
# No (0) instance child feature: 8
# Yes (1) instance child feature: 8
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 75 with depth 6
# Subset features rows 7
# targets rows 7
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 15
# No (0) instance child feature: 4
# Yes (1) instance child feature: 4
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 79 with depth 6
# Subset features rows 21
# targets rows 21
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 6
# No (0) instance child feature: 11
# Yes (1) instance child feature: 11
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 80 with depth 6
# Subset features rows 14
# targets rows 14
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 9
# No (0) instance child feature: 1
# Yes (1) instance child feature: 8
#
# Distributing to children from pure node 162...
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 81 with depth 6
# Subset features rows 8
# targets rows 8
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 8
# No (0) instance child feature: 13
# Yes (1) instance child feature: 13
#
# Distributing to children from pure node 164...
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 82 with depth 6
# Subset features rows 18
# targets rows 18
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 7
# No (0) instance child feature: 9
# Yes (1) instance child feature: 1
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 83 with depth 6
# Subset features rows 9
# targets rows 9
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 5
# No (0) instance child feature: 6
# Yes (1) instance child feature: 6
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 85 with depth 6
# Subset features rows 9
# targets rows 9
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 6
# No (0) instance child feature: 7
# Yes (1) instance child feature: 7
#
# Distributing to children from pure node 171...
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 86 with depth 6
# Subset features rows 11
# targets rows 11
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 15
# No (0) instance child feature: 13
# Yes (1) instance child feature: 13
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 87 with depth 6
# Subset features rows 7
# targets rows 7
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 5
# No (0) instance child feature: 9
# Yes (1) instance child feature: 9
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 88 with depth 6
# Subset features rows 18
# targets rows 18
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 9
# No (0) instance child feature: 15
# Yes (1) instance child feature: 15
#
# Distributing to children from pure node 177...
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 90 with depth 6
# Subset features rows 6
# targets rows 6
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 15
# No (0) instance child feature: 9
# Yes (1) instance child feature: 9
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 91 with depth 6
# Subset features rows 3
# targets rows 3
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 15
# No (0) instance child feature: 1
# Yes (1) instance child feature: 1
#
# Distributing to children from pure node 184...
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 95 with depth 6
# Subset features rows 5
# targets rows 5
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 6
# No (0) instance child feature: 10
# Yes (1) instance child feature: 10
#
# Distributing to children from pure node 191...
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 98 with depth 6
# Subset features rows 5
# targets rows 5
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 13
# No (0) instance child feature: 11
# Yes (1) instance child feature: 7
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 115 with depth 6
# Subset features rows 12
# targets rows 12
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 1
# No (0) instance child feature: 6
# Yes (1) instance child feature: 6
# new depth of tree 8
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 127 with depth 7
#
#  tree getting to deep ... stopping the building

# %%
r_test = forest.predict(features_test)
#r_test = r_test.astype(int)
result_test = pd.DataFrame({
    'y': targets_test,
    'prediction': r_test
})

#print(result_test)
# Out:
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None

# %%
from sklearn.metrics import matthews_corrcoef

mcc_test = matthews_corrcoef(result_test['y'], result_test['prediction'])
print(mcc_test)
# Out:
# 0.15806846388953513
