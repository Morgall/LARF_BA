# %%
from tree_refactored.class_tree import DecisionTree_rollOCT

import numpy as np
import pandas as pd

#from sklearn.base import BaseEstimator, ClassifierMixin, clone

from scipy.stats import mode
import multiprocessing

def fit_single_tree(args):
    X, y, max_depth, max_features, random_state = args
    rng = np.random.RandomState(random_state)
    indices = np.array(X.index)
    sample_indices = rng.choice(indices, size=len(indices), replace=True)
    #sample_indices = rng.choice(indices, size=int(np.sqrt(len(indices))), replace=False) # Picks len(indices) samples with replacement => means some rows will repeat, others will be omitted → those omitted are "out-of-bag" (OOB)
    oob_mask = ~np.isin(indices, sample_indices)
    oob_indices = indices[oob_mask]

    X_boot = X.loc[sample_indices]
    y_boot = y.loc[sample_indices]
    train_data = pd.concat([y_boot, X_boot], axis=1)
    train_data.columns = ['y'] + list(range(X.shape[1]))

    if len(oob_indices) > 0:
        X_oob = X.loc[oob_indices]
        y_oob = y.loc[oob_indices]
        test_data = pd.concat([y_oob, X_oob], axis=1)
        test_data.columns = ['y'] + list(range(X.shape[1]))
    else:
        test_data = train_data.copy()

    tree = DecisionTree_rollOCT(max_depth=max_depth, max_features = max_features)
    tree.fit(X_boot, y_boot)
    return tree, (sample_indices, oob_indices)


class CustomForestClassifier:
    def __init__(self, n_estimators=10, random_state=None, cores_to_use = 1, max_depth=8, max_features=None):
        """
        n_estimators: number of trees in the ensemble
        tree_kwargs: dictionary of keyword args for CustomTreeWrapper (except train_data and test_data)
        random_state: seed for reproducible bootstrap sampling
        """
        self.n_estimators = n_estimators
        self.max_depth = max_depth          #max depth of a tree
        self.max_features = max_features    #features used in each split in tree
        #self.tree_kwargs = tree_kwargs if tree_kwargs is not None else {}
        self.random_state = random_state
        self.trees_ = []
        self.bootstrap_indices_ = []
        self.cores_to_use = cores_to_use

    def fit(self, X, y): # uses parallel fit directly
        #num_cores_to_use = 6
        pool = multiprocessing.Pool(processes=self.cores_to_use)
        random_states = [self.random_state + i for i in range(self.n_estimators)] if self.random_state is not None else [None]*self.n_estimators
        args = [(X, y, self.max_depth,self.max_features , rs) for rs in random_states]

        results = pool.map(fit_single_tree, args)
        pool.close()
        pool.join()

        self.trees_ = [res[0] for res in results] #rebuilds the classifier’s internal list of trained trees from the results returned by pool.map()
        self.bootstrap_indices_ = [res[1] for res in results]
        return self
  

    def predict(self, X):
        """
        Majority-vote ensemble prediction.
        Returns: pd.Series with predictions, aligned to X.index
        """
        # Aggregate predictions (each as Series aligned to X.index)
        all_preds = pd.DataFrame()
        for tree in self.trees_:
            pred = tree.predict(X)
            pred  = pred.astype(int)
            all_preds = pd.concat([all_preds, pred], axis=1)
        # row-wise majority vote (handle multiple modes by picking first)
        maj_vote = all_preds.mode(axis=1)[0]
        maj_vote.index = X.index  # ensure correct alignment
        maj_vote = maj_vote.astype(int)
        return maj_vote

    def predict_proba(self, X):
        """
        For binary classification:
        Returns an array of shape (n_samples, 2)
        """
        all_preds = []
        for tree in self.trees_:
            pred = tree.predict(X)
            if not isinstance(pred, pd.Series):
                pred = pd.Series(pred, index=X.index)
            all_preds.append(pred)
        preds_matrix = pd.concat(all_preds, axis=1)

        # Works for binary or multiclass
        classes_ = np.unique(preds_matrix.values)
        proba = np.zeros((X.shape[0], len(classes_)))
        for i, c in enumerate(classes_):
            proba[:, i] = (preds_matrix == c).sum(axis=1) / self.n_estimators
        return proba

    def oob_score(self, X, y):
        """
        Returns out-of-bag score.
        """
        # Prepare OOB predictions
        oob_votes = {idx: [] for idx in X.index}
        for (sample_ind, oob_ind), tree in zip(self.bootstrap_indices_, self.trees_):
            if len(oob_ind) == 0:
                continue
            X_oob = X.loc[oob_ind]
            preds = tree.predict(X_oob)
            for idx, pred in preds.items():
                oob_votes[idx].append(pred)
        # Only score samples with at least one OOB prediction
        final_oob_preds = []
        final_oob_true = []
        for idx, votes in oob_votes.items():
            if votes:
                final_oob_preds.append(mode(votes)[0][0])
                final_oob_true.append(y.loc[idx])
        if not final_oob_preds:
            raise ValueError("No OOB predictions collected.")
        accuracy = np.mean(np.array(final_oob_preds) == np.array(final_oob_true))
        return accuracy

# %%
#data_seismic = pd.read_csv("datasets/seismic/seismic_bin.csv")
data_test = pd.read_csv("datasets/example_datasets/stacked.csv")
data_spambase = pd.read_csv("datasets/spambase/spambase_bin.csv")
data_nursery = pd.read_csv("datasets/nursery/nursery_bin.csv")
data_adult = pd.read_csv("datasets/adult/stacked.csv")
data_monk2 = pd.read_csv("datasets/monk2/monk2_bin.csv")

data = data_monk2

# %%
from sklearn.model_selection import StratifiedKFold

skf = StratifiedKFold(n_splits=2, shuffle=True, random_state=42)
tree_kwargs = dict(depth=8)

features = data.drop(columns=['y'])
targets = data['y']

for train_idx, test_idx in skf.split(features, targets): #gives row indices
    
    
    features_train = features.iloc[train_idx]
    features_test = features.iloc[test_idx]
    targets_train = targets.iloc[train_idx]
    targets_test = targets.iloc[test_idx]

    forest = CustomForestClassifier(n_estimators=50, random_state=42, cores_to_use=1, max_depth=8, max_features='sqrt')

# %%
forest.fit(features_train, targets_train)
# Out:
# Training each tree split on 3 features of all 15 featuresTraining each tree split on 3 features of all 15 featuresTraining each tree split on 3 features of all 15 featuresTraining each tree split on 3 features of all 15 features
#
#
#
#
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
#
#
#
# queue empty: False
#
# queue empty: False
# queue empty: False
#
# queue empty: False
#
#
# Working on node number 0 with depth 0
#
# Working on node number 0 with depth 0
# Working on node number 0 with depth 0
#
# Working on node number 0 with depth 0
#
#
# Subset features rows 301Subset features rows 301Subset features rows 301
# Subset features rows 301
#
#
# targets rows 301targets rows 301targets rows 301
# targets rows 301
#
#
# Preprocessing ...
#
# Preprocessing ...
#
# Preprocessing ...
# Preprocessing ...
#
#
#
# Finding features for subtree
# Finding features for subtree
# Finding features for subtree
# Finding features for subtree
#
#
#
#
# Selected features subtree:
# Selected features subtree:
# Selected features subtree:
# Selected features subtree:
#
#
#
# Root Node Feature: 10Root Node Feature: 4Root Node Feature: 1Root Node Feature: 7
#
#
#
# No (0) instance child feature: 3No (0) instance child feature: 13No (0) instance child feature: 15No (0) instance child feature: 13
#
#
#
# Yes (1) instance child feature: 3Yes (1) instance child feature: 3Yes (1) instance child feature: 12Yes (1) instance child feature: 13
#
#
#
# new depth of tree 2new depth of tree 2new depth of tree 2new depth of tree 2
#
#
#
#
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
#
#
#
#
# queue empty: False
# queue empty: False
# queue empty: False
# queue empty: False
#
#
#
#
# Working on node number 1 with depth 1
# Working on node number 1 with depth 1
# Working on node number 1 with depth 1
# Working on node number 1 with depth 1
#
#
#
# Subset features rows 213Subset features rows 130Subset features rows 193Subset features rows 195
#
#
#
# targets rows 213targets rows 130targets rows 193targets rows 195
#
#
#
#
# Preprocessing ...
# Preprocessing ...
# Preprocessing ...
# Preprocessing ...
#
#
#
#
# Finding features for subtree
# Finding features for subtree
# Finding features for subtree
# Finding features for subtree
#
#
#
#
# Selected features subtree:
# Selected features subtree:
# Selected features subtree:
# Selected features subtree:
#
#
#
# Root Node Feature: 11Root Node Feature: 15Root Node Feature: 5Root Node Feature: 12
#
#
#
# No (0) instance child feature: 2No (0) instance child feature: 8No (0) instance child feature: 11No (0) instance child feature: 6
#
#
#
# Yes (1) instance child feature: 3Yes (1) instance child feature: 2Yes (1) instance child feature: 15Yes (1) instance child feature: 6
#
#
#
# new depth of tree 3new depth of tree 3new depth of tree 3new depth of tree 3
#
#
#
#
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
#
#
#
#
# queue empty: False
# queue empty: False
# queue empty: False
# queue empty: False
#
#
#
#
# Working on node number 2 with depth 1
# Working on node number 2 with depth 1
# Working on node number 2 with depth 1
# Working on node number 2 with depth 1
#
#
#
# Subset features rows 88Subset features rows 108Subset features rows 171Subset features rows 106
#
#
#
# targets rows 88targets rows 108targets rows 171targets rows 106
#
#
#
#
# Preprocessing ...
# Preprocessing ...
# Preprocessing ...
# Preprocessing ...
#
#
#
#
# Finding features for subtree
# Finding features for subtree
# Finding features for subtree
#
# Finding features for subtree
#
#
#
# Selected features subtree:
# Selected features subtree:
# Selected features subtree:
# Selected features subtree:
#
#
#
# Root Node Feature: 11Root Node Feature: 8Root Node Feature: 15Root Node Feature: 9
#
#
#
# No (0) instance child feature: 4No (0) instance child feature: 1No (0) instance child feature: 9No (0) instance child feature: 13
#
#
#
# Yes (1) instance child feature: 8Yes (1) instance child feature: 1Yes (1) instance child feature: 12Yes (1) instance child feature: 13
#
#
#
# new depth of tree 3new depth of tree 3new depth of tree 3new depth of tree 3
#
#
#
#
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
#
#
#
#
# queue empty: False
# queue empty: False
# queue empty: False
# queue empty: False
#
#
#
#
# Working on node number 3 with depth 2
# Working on node number 3 with depth 2
# Working on node number 3 with depth 2
# Working on node number 3 with depth 2
#
#
#
# Subset features rows 140Subset features rows 129Subset features rows 96Subset features rows 161
#
#
#
# targets rows 129targets rows 96targets rows 140targets rows 161
#
#
#
#
# Preprocessing ...
# Preprocessing ...
# Preprocessing ...
# Preprocessing ...
#
#
#
#
# Finding features for subtree
# Finding features for subtree
# Finding features for subtree
#
#
# Finding features for subtree
#
#
# Selected features subtree:
# Selected features subtree:
# Selected features subtree:
# Selected features subtree:
#
#
#
# Root Node Feature: 11Root Node Feature: 6Root Node Feature: 1Root Node Feature: 3
#
#
#
# No (0) instance child feature: 12No (0) instance child feature: 1No (0) instance child feature: 15
# No (0) instance child feature: 15
#
# Yes (1) instance child feature: 12
# Yes (1) instance child feature: 1Yes (1) instance child feature: 12
# Yes (1) instance child feature: 15
#
#
# new depth of tree 4
# new depth of tree 4new depth of tree 4new depth of tree 4
# ----------------------------------------
#
#
#
# ----------------------------------------
#
# ----------------------------------------
# queue empty: False
#
#
# ----------------------------------------
#
# queue empty: False
#
# queue empty: False
# Working on node number 4 with depth 2
#
#
# queue empty: False
#
# Working on node number 4 with depth 2
# Working on node number 4 with depth 2
#
#
#
# Working on node number 4 with depth 2Subset features rows 34
# Subset features rows 64
# Subset features rows 55
#
# targets rows 34Subset features rows 52targets rows 64
#
# targets rows 55
#
# Preprocessing ...
#
# Preprocessing ...
# targets rows 52
# Preprocessing ...
#
#
#
# Preprocessing ...
# Finding features for subtree
#
#
# Finding features for subtree
# Finding features for subtree
#
#
# Finding features for subtree
#
# Selected features subtree:
# Selected features subtree:
# Selected features subtree:
#
#
#
# Selected features subtree:Root Node Feature: 7Root Node Feature: 1
# Root Node Feature: 6
#
# Root Node Feature: 14No (0) instance child feature: 1
# No (0) instance child feature: 4
#
# No (0) instance child feature: 2
# No (0) instance child feature: 3Yes (1) instance child feature: 8
# Yes (1) instance child feature: 4
#
# Yes (1) instance child feature: 3
# Yes (1) instance child feature: 2
#
# new depth of tree 4new depth of tree 4
#
#
# ----------------------------------------
# new depth of tree 4
# ----------------------------------------new depth of tree 4
# queue empty: False
#
#
#
#
# ----------------------------------------
# queue empty: False
# ----------------------------------------
# Working on node number 5 with depth 2
#
#
#
#
# Working on node number 5 with depth 2
# queue empty: False
# queue empty: False
#
#
# Subset features rows 115
# Working on node number 5 with depth 2
# Working on node number 5 with depth 2
#
# Subset features rows 55
# targets rows 115
#
# Subset features rows 77Subset features rows 90
# Preprocessing ...
# targets rows 55
#
# targets rows 77
# targets rows 90
#
# Preprocessing ...
#
# Preprocessing ...
#
# Finding features for subtree
# Preprocessing ...
#
#
#
# Finding features for subtree
# Finding features for subtree
# Finding features for subtree
#
#
#
# Selected features subtree:
#
# Selected features subtree:
# Selected features subtree:Root Node Feature: 1
#
#
#
# Selected features subtree:Root Node Feature: 12Root Node Feature: 6No (0) instance child feature: 3
#
#
#
# Root Node Feature: 11No (0) instance child feature: 6No (0) instance child feature: 8Yes (1) instance child feature: 3
#
#
#
# No (0) instance child feature: 1Yes (1) instance child feature: 6Yes (1) instance child feature: 15
#
#
# Yes (1) instance child feature: 14
# new depth of tree 4new depth of tree 4
#
# new depth of tree 4
# ----------------------------------------new depth of tree 4
# ----------------------------------------
#
#
#
#
# ----------------------------------------
# queue empty: False
# ----------------------------------------
# queue empty: False
#
#
#
#
# queue empty: False
# Working on node number 6 with depth 2
# queue empty: False
# Working on node number 6 with depth 2
#
#
#
# Working on node number 6 with depth 2
#
# Working on node number 6 with depth 2
#
# Subset features rows 56Subset features rows 29
#
# Subset features rows 33Subset features rows 18targets rows 56
# targets rows 29
#
#
# targets rows 33
# Preprocessing ...targets rows 18
# Preprocessing ...
#
#
#
#
# Preprocessing ...
#
# Preprocessing ...
#
# Finding features for subtree
# Finding features for subtree
#
#
# Finding features for subtree
# Finding features for subtree
#
#
# Selected features subtree:
# Selected features subtree:
#
#
# Selected features subtree:
# Selected features subtree:Root Node Feature: 4Root Node Feature: 6
#
#
#
# Root Node Feature: 2Root Node Feature: 7No (0) instance child feature: 6No (0) instance child feature: 2
#
#
#
# No (0) instance child feature: 13No (0) instance child feature: 2Yes (1) instance child feature: 14Yes (1) instance child feature: 2
#
#
#
# Yes (1) instance child feature: 13Yes (1) instance child feature: 2
#
# new depth of tree 4
# Distributing to children from pure node 14...new depth of tree 4
#
# new depth of tree 4
#
# ----------------------------------------
#
# ----------------------------------------
#
# ----------------------------------------
#
# queue empty: Falsenew depth of tree 4
# queue empty: False
#
#
#
#
# Working on node number 7 with depth 3
# queue empty: False
# ----------------------------------------
# Working on node number 7 with depth 3
#
#
#
#
# Working on node number 7 with depth 3
# queue empty: FalseSubset features rows 63
#
#
# Subset features rows 73
# Working on node number 7 with depth 3Subset features rows 73
#
#
# targets rows 63targets rows 73
# Subset features rows 72targets rows 73
#
# Preprocessing ...
#
#
#
# Preprocessing ...
# Preprocessing ...targets rows 72
#
#
#
# Finding features for subtree
# Preprocessing ...
#
# Finding features for subtree
# Finding features for subtree
#
#
#
# Finding features for subtree
#
# Selected features subtree:
# Selected features subtree:
#
#
# Selected features subtree:Root Node Feature: 3Root Node Feature: 1
#
#
# Root Node Feature: 1No (0) instance child feature: 13No (0) instance child feature: 6
# Selected features subtree:
#
#
#
# Yes (1) instance child feature: 13No (0) instance child feature: 3Root Node Feature: 10Yes (1) instance child feature: 6
#
#
#
# Yes (1) instance child feature: 3No (0) instance child feature: 8
#
# Yes (1) instance child feature: 6
# new depth of tree 5new depth of tree 5
# new depth of tree 5
#
# ----------------------------------------
# ----------------------------------------
#
# ----------------------------------------
# new depth of tree 5
#
# queue empty: False
#
#
# queue empty: False
#
# ----------------------------------------
# queue empty: False
#
# Working on node number 8 with depth 3
#
#
# Working on node number 8 with depth 3
#
# Working on node number 8 with depth 3
# queue empty: False
#
#
# Subset features rows 77
# Working on node number 8 with depth 3Subset features rows 23
# Subset features rows 88
#
#
# targets rows 77targets rows 23
# targets rows 88Subset features rows 57
#
# Preprocessing ...
#
#
# Preprocessing ...
#
# Preprocessing ...
# targets rows 57
#
#
# Preprocessing ...
# Finding features for subtree
# Finding features for subtree
#
#
# Finding features for subtree
#
#
# Finding features for subtree
#
# Selected features subtree:
# Selected features subtree:
# Selected features subtree:
#
#
# Root Node Feature: 6Root Node Feature: 2Root Node Feature: 3
# Selected features subtree:
#
#
#
# No (0) instance child feature: 1No (0) instance child feature: 13No (0) instance child feature: 8Root Node Feature: 8
#
#
#
# Yes (1) instance child feature: 13Yes (1) instance child feature: 8Yes (1) instance child feature: 6No (0) instance child feature: 13
#
#
#
# Yes (1) instance child feature: 13
#
# Distributing to children from pure node 18...
# new depth of tree 5new depth of tree 5
#
# new depth of tree 5
# ----------------------------------------
# ----------------------------------------
# new depth of tree 5
#
#
# ----------------------------------------
#
# queue empty: False
# queue empty: False
#
# ----------------------------------------
#
# queue empty: False
#
#
# Working on node number 9 with depth 3
#
# queue empty: False
# Working on node number 9 with depth 3
#
# Working on node number 9 with depth 3
#
#
#
# Working on node number 9 with depth 3Subset features rows 40
# Subset features rows 28
# Subset features rows 23
# Subset features rows 47
# targets rows 40
#
# targets rows 28targets rows 23
# Preprocessing ...
# targets rows 47
#
#
# Preprocessing ...
#
# Preprocessing ...
#
# Preprocessing ...
#
#
# Finding features for subtree
#
# Finding features for subtree
# Finding features for subtree
#
#
# Finding features for subtree
#
# Selected features subtree:
# Selected features subtree:
# Selected features subtree:
#
#
#
# Selected features subtree:Root Node Feature: 8Root Node Feature: 8Root Node Feature: 12
#
#
#
# Root Node Feature: 15No (0) instance child feature: 13No (0) instance child feature: 13
# No (0) instance child feature: 9
#
# No (0) instance child feature: 11Yes (1) instance child feature: 13
# Yes (1) instance child feature: 13
#
# Yes (1) instance child feature: 9
# Yes (1) instance child feature: 12
#
#
# Distributing to children from pure node 19...
# new depth of tree 5new depth of tree 5new depth of tree 5
#
#
#
# ----------------------------------------new depth of tree 5
# ----------------------------------------
# ----------------------------------------
#
#
#
#
# queue empty: False
# ----------------------------------------
# queue empty: False
# queue empty: False
#
#
#
#
# Working on node number 10 with depth 3
# queue empty: False
# Working on node number 10 with depth 3
# Working on node number 10 with depth 3
#
#
#
#
# Working on node number 10 with depth 3
# Subset features rows 12Subset features rows 11Subset features rows 17
#
#
# Subset features rows 27targets rows 12
# targets rows 17targets rows 11
#
#
# targets rows 27
# Preprocessing ...
# Preprocessing ...
# Preprocessing ...
#
#
#
#
# Preprocessing ...
#
# Finding features for subtree
# Finding features for subtree
# Finding features for subtree
#
#
# Finding features for subtree
#
#
# Selected features subtree:
# Selected features subtree:
# Selected features subtree:
#
#
# Selected features subtree:
# Root Node Feature: 1Root Node Feature: 4Root Node Feature: 11
#
# Root Node Feature: 5
#
#
# No (0) instance child feature: 8No (0) instance child feature: 3No (0) instance child feature: 6No (0) instance child feature: 9
#
#
#
# Yes (1) instance child feature: 8Yes (1) instance child feature: 3Yes (1) instance child feature: 6Yes (1) instance child feature: 9
#
#
#
# new depth of tree 5
# Distributing to children from pure node 22...
# new depth of tree 5
#
# ----------------------------------------
#
# new depth of tree 5
# ----------------------------------------
# queue empty: False
#
# new depth of tree 5
# ----------------------------------------
#
# queue empty: False
#
#
# Working on node number 11 with depth 3
#
# ----------------------------------------
# queue empty: False
#
# Working on node number 12 with depth 3
#
#
#
# queue empty: False
# Working on node number 11 with depth 3
# Subset features rows 67
#
# Working on node number 11 with depth 3
# Subset features rows 115
#
# Subset features rows 77targets rows 67
# targets rows 115Subset features rows 36
#
#
#
# Preprocessing ...targets rows 77
# Preprocessing ...
#
# targets rows 36
#
# Preprocessing ...
#
#
# Preprocessing ...
# Finding features for subtree
#
# Finding features for subtree
#
#
# Finding features for subtree
#
# Finding features for subtree
#
# Selected features subtree:
#
# Selected features subtree:
# Selected features subtree:Root Node Feature: 5
#
#
# Root Node Feature: 8
# Selected features subtree:Root Node Feature: 6No (0) instance child feature: 3
#
#
# No (0) instance child feature: 13Root Node Feature: 2
# No (0) instance child feature: 8
#
# Yes (1) instance child feature: 3
# No (0) instance child feature: 1Yes (1) instance child feature: 13
# Yes (1) instance child feature: 14
#
#
# Yes (1) instance child feature: 1
# new depth of tree 5
# new depth of tree 5
# ----------------------------------------
# new depth of tree 5
#
# ----------------------------------------
#
# queue empty: False
#
# ----------------------------------------new depth of tree 5
# queue empty: False
#
#
#
#
# queue empty: False
# ----------------------------------------
# Working on node number 12 with depth 3
# Working on node number 13 with depth 3
#
#
#
#
# queue empty: False
# Working on node number 13 with depth 3
#
# Subset features rows 23
# Working on node number 12 with depth 3Subset features rows 21
#
#
# Subset features rows 39targets rows 23
#
# Subset features rows 19targets rows 21
#
# Preprocessing ...targets rows 39
#
# Preprocessing ...
#
#
# targets rows 19
# Preprocessing ...
#
# Finding features for subtree
#
# Preprocessing ...
#
# Finding features for subtree
#
#
# Finding features for subtree
#
# Finding features for subtree
#
# Selected features subtree:
# Selected features subtree:
#
# Root Node Feature: 12Root Node Feature: 8
# Selected features subtree:
#
#
# No (0) instance child feature: 5No (0) instance child feature: 3
# Selected features subtree:Root Node Feature: 6
#
#
# Yes (1) instance child feature: 5
# Yes (1) instance child feature: 3
# Root Node Feature: 4
# new depth of tree 5No (0) instance child feature: 4No (0) instance child feature: 11
#
#
#
# ----------------------------------------Yes (1) instance child feature: 4
#
#
# Yes (1) instance child feature: 11
# queue empty: False
#
# new depth of tree 5
# new depth of tree 5
# Working on node number 13 with depth 3
#
#
# ----------------------------------------
#
# ----------------------------------------Subset features rows 8
#
# queue empty: Falsenew depth of tree 5
# queue empty: False
#
#
#
#
# Working on node number 14 with depth 3targets rows 8
# ----------------------------------------
# Working on node number 14 with depth 3
#
#
#
#
# queue empty: False
# Preprocessing ...
#
# Subset features rows 8
# Working on node number 13 with depth 3Subset features rows 17
#
# Finding features for subtreeSubset features rows 33
#
#
#
# targets rows 17targets rows 33targets rows 8
#
#
#
# Preprocessing ...
# Preprocessing ...
# Selected features subtree:
# Preprocessing ...
#
# Root Node Feature: 14
#
#
# No (0) instance child feature: 6
# Finding features for subtree
#
# Finding features for subtree
# Yes (1) instance child feature: 8
# Finding features for subtree
#
#
# new depth of tree 5
#
# Selected features subtree:
# Selected features subtree:
#
#
# Selected features subtree:
# ----------------------------------------Root Node Feature: 4Root Node Feature: 12
#
#
#
# Root Node Feature: 14No (0) instance child feature: 15
# queue empty: FalseNo (0) instance child feature: 6
#
#
#
# Yes (1) instance child feature: 14
# Working on node number 15 with depth 4No (0) instance child feature: 8Yes (1) instance child feature: 6
#
#
#
# Yes (1) instance child feature: 15
# Subset features rows 36
# targets rows 36new depth of tree 5
# new depth of tree 5new depth of tree 5
#
# Preprocessing ...
#
#
#
# ----------------------------------------
# ----------------------------------------
# Finding features for subtree
#
# ----------------------------------------
#
# queue empty: False
#
#
# queue empty: False
#
#
# queue empty: False
# Working on node number 15 with depth 4
# Working on node number 15 with depth 4
#
#
# Working on node number 15 with depth 4
#
# Subset features rows 73Subset features rows 73
#
# Subset features rows 45targets rows 73
# targets rows 73
#
# targets rows 45
# Selected features subtree:
# Preprocessing ...
# Preprocessing ...
#
#
#
#
# Preprocessing ...Root Node Feature: 7
#
# No (0) instance child feature: 14
# Finding features for subtree
# Finding features for subtree
#
#
# Finding features for subtree
#
# Yes (1) instance child feature: 14
# new depth of tree 6
# Selected features subtree:
# Selected features subtree:
#
# Selected features subtree:
#
#
# ----------------------------------------
# Root Node Feature: 12Root Node Feature: 14
# Root Node Feature: 2
#
#
#
# queue empty: FalseNo (0) instance child feature: 6No (0) instance child feature: 14No (0) instance child feature: 1
#
#
#
#
# Working on node number 16 with depth 4Yes (1) instance child feature: 6Yes (1) instance child feature: 14Yes (1) instance child feature: 11
#
#
#
# Subset features rows 36
# targets rows 36
#
# Preprocessing ...new depth of tree 6new depth of tree 6
#
#
# new depth of tree 6
# ----------------------------------------
# ----------------------------------------
#
#
#
# Finding features for subtree
# ----------------------------------------
# queue empty: False
# queue empty: False
#
#
#
#
# Working on node number 17 with depth 4
# queue empty: False
# Working on node number 17 with depth 4
#
#
#
# Working on node number 16 with depth 4
# Subset features rows 67Subset features rows 20
#
# Subset features rows 18targets rows 67
# targets rows 20
#
#
# Preprocessing ...targets rows 18
# Preprocessing ...
#
#
#
# Preprocessing ...
#
# Selected features subtree:
#
# Finding features for subtree
# Finding features for subtreeRoot Node Feature: 1
#
#
#
# Finding features for subtree
# No (0) instance child feature: 15
# Yes (1) instance child feature: 14
#
# Selected features subtree:
# Selected features subtree:
# Selected features subtree:
#
#
# Root Node Feature: 1new depth of tree 6Root Node Feature: 12Root Node Feature: 15
#
#
#
#
# ----------------------------------------No (0) instance child feature: 5No (0) instance child feature: 2No (0) instance child feature: 11
#
#
#
#
# queue empty: FalseYes (1) instance child feature: 5Yes (1) instance child feature: 11Yes (1) instance child feature: 13
#
#
#
#
# Working on node number 17 with depth 4
# Subset features rows 37
# new depth of tree 6targets rows 37new depth of tree 6
#
#
# new depth of tree 6
# ----------------------------------------
# Preprocessing ...
# ----------------------------------------
#
#
#
#
# ----------------------------------------
# queue empty: False
# queue empty: False
#
#
#
# queue empty: False
# Working on node number 19 with depth 4
# Finding features for subtree
# Working on node number 17 with depth 4
#
#
#
#
# Working on node number 18 with depth 4
# Subset features rows 23Subset features rows 35
#
# Subset features rows 21
# targets rows 23targets rows 35
#
# targets rows 21
# Preprocessing ...
# Preprocessing ...
#
#
#
# Preprocessing ...
#
# Selected features subtree:
# Finding features for subtree
#
# Finding features for subtree
#
# Root Node Feature: 7
# Finding features for subtree
#
# No (0) instance child feature: 2
# Yes (1) instance child feature: 2
#
# Selected features subtree:
# Selected features subtree:
#
# Selected features subtree:
# Root Node Feature: 6
# Root Node Feature: 2new depth of tree 6
# Root Node Feature: 8
# No (0) instance child feature: 14
#
# No (0) instance child feature: 5
#
# ----------------------------------------No (0) instance child feature: 10
# Yes (1) instance child feature: 14
#
# Yes (1) instance child feature: 5
#
#
# queue empty: FalseYes (1) instance child feature: 15
#
#
# Working on node number 18 with depth 4
# Subset features rows 20new depth of tree 6new depth of tree 6
#
#
# new depth of tree 6
# ----------------------------------------
# ----------------------------------------
#
# targets rows 20
#
# ----------------------------------------
#
# queue empty: False
# queue empty: False
#
# Preprocessing ...
#
#
# queue empty: False
# Working on node number 18 with depth 4
#
#
# Working on node number 21 with depth 4
#
# Working on node number 19 with depth 4
#
#
# Finding features for subtreeSubset features rows 7Subset features rows 42Subset features rows 32
#
#
#
# targets rows 7targets rows 32targets rows 42
#
#
#
# Preprocessing ...
# Preprocessing ...
# Preprocessing ...
#
#
#
# Finding features for subtree
# Finding features for subtree
# Finding features for subtree
#
#
#
# Selected features subtree:
# Root Node Feature: 14
# No (0) instance child feature: 1
# Yes (1) instance child feature: 10
#
# Selected features subtree:
# Selected features subtree:
#
# Selected features subtree:
# Root Node Feature: 6
# Root Node Feature: 1
# Root Node Feature: 9
# No (0) instance child feature: 13
# No (0) instance child feature: 2
# No (0) instance child feature: 5
# Yes (1) instance child feature: 13
# Yes (1) instance child feature: 2
# new depth of tree 6Yes (1) instance child feature: 13
#
#
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 19 with depth 4
# new depth of tree 6new depth of tree 6
# Subset features rows 38
#
# ----------------------------------------
# ----------------------------------------
#
#
# new depth of tree 6
# queue empty: False
#
#
# queue empty: False
# Working on node number 22 with depth 4
# ----------------------------------------
#
#
# Working on node number 20 with depth 4
#
#
# queue empty: FalseSubset features rows 4targets rows 38
#
#
#
# Working on node number 20 with depth 4Subset features rows 8
# Preprocessing ...
# targets rows 4
#
#
#
# Preprocessing ...Subset features rows 15targets rows 8
#
#
#
# Finding features for subtree
# Preprocessing ...targets rows 15
#
#
#
# Finding features for subtree
# Preprocessing ...
#
#
# Finding features for subtree
#
# Finding features for subtree
#
# Selected features subtree:
#
# Selected features subtree:Root Node Feature: 8
#
# Root Node Feature: 15No (0) instance child feature: 13
# No (0) instance child feature: 6
#
# Selected features subtree:Yes (1) instance child feature: 13
#
#
# Selected features subtree:Yes (1) instance child feature: 6Root Node Feature: 13
#
#
#
# Root Node Feature: 11No (0) instance child feature: 11
#
# No (0) instance child feature: 1Yes (1) instance child feature: 11
#
# Yes (1) instance child feature: 1new depth of tree 6
#
# new depth of tree 6
# ----------------------------------------
#
# ----------------------------------------
#
#
# queue empty: False
#
# queue empty: False
# Distributing to children from pure node 42...
#
# Working on node number 25 with depth 4new depth of tree 6
#
#
# Working on node number 20 with depth 4
#
#
# ----------------------------------------
# Subset features rows 73new depth of tree 6Subset features rows 9
# queue empty: False
#
#
#
#
# ----------------------------------------targets rows 73
# Working on node number 21 with depth 4targets rows 9
#
#
#
#
# queue empty: False
# Preprocessing ...
# Preprocessing ...
#
# Subset features rows 9
#
# Working on node number 21 with depth 4
#
# targets rows 9
# Finding features for subtree
# Finding features for subtreeSubset features rows 16
#
#
#
# Preprocessing ...
#
# targets rows 16
#
# Preprocessing ...
# Finding features for subtree
#
#
# Selected features subtree:
# Selected features subtree:
# Finding features for subtree
#
#
# Root Node Feature: 7Root Node Feature: 9
#
# No (0) instance child feature: 4No (0) instance child feature: 14
# Yes (1) instance child feature: 4
# Yes (1) instance child feature: 14
#
# Selected features subtree:
#
#
# Selected features subtree:new depth of tree 6Root Node Feature: 2
#
# No (0) instance child feature: 9
# ----------------------------------------
#
#
# new depth of tree 6Root Node Feature: 3Yes (1) instance child feature: 9
#
# queue empty: False
#
#
# No (0) instance child feature: 6
#
# ----------------------------------------Yes (1) instance child feature: 6new depth of tree 6
#
#
# Working on node number 21 with depth 4
#
#
# ----------------------------------------Subset features rows 17
# queue empty: False
#
# new depth of tree 6
# queue empty: False
# Working on node number 26 with depth 4
#
#
#
# targets rows 17
# Working on node number 23 with depth 4
# ----------------------------------------
#
# Subset features rows 42
#
#
# Preprocessing ...
# queue empty: False
# Subset features rows 19
# targets rows 42
#
# Working on node number 22 with depth 4
#
#
# Preprocessing ...
# Finding features for subtreetargets rows 19
#
# Subset features rows 11
#
#
# Preprocessing ...
# Finding features for subtree
# targets rows 11
#
#
# Preprocessing ...
#
# Finding features for subtree
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 2
# Selected features subtree:
#
# No (0) instance child feature: 12
# Selected features subtree:Root Node Feature: 15
#
# Yes (1) instance child feature: 11
# Selected features subtree:
# Root Node Feature: 13
# No (0) instance child feature: 7
#
# No (0) instance child feature: 7
# Root Node Feature: 8Yes (1) instance child feature: 14
#
#
# Yes (1) instance child feature: 7No (0) instance child feature: 9
#
#
# Distributing to children from pure node 43...Yes (1) instance child feature: 9
#
#
# Distributing to children from pure node 54...
# new depth of tree 6
#
# ----------------------------------------new depth of tree 6new depth of tree 6
#
#
#
# ----------------------------------------
# queue empty: False
# ----------------------------------------new depth of tree 6
#
#
#
#
# queue empty: False
# queue empty: False
# Working on node number 23 with depth 4
# ----------------------------------------
#
#
#
#
# Working on node number 24 with depth 4
# Working on node number 27 with depth 4
# queue empty: False
#
# Subset features rows 67
#
#
# Working on node number 23 with depth 4Subset features rows 17Subset features rows 39
#
# targets rows 67
#
# targets rows 17Subset features rows 77
# Preprocessing ...targets rows 39
#
#
#
#
# Preprocessing ...
# Preprocessing ...
# targets rows 77
#
#
# Finding features for subtree
# Preprocessing ...
#
# Finding features for subtree
#
#
# Finding features for subtree
#
# Finding features for subtree
#
# Selected features subtree:
# Selected features subtree:
#
# Root Node Feature: 6Root Node Feature: 10
# Selected features subtree:
#
#
# Selected features subtree:No (0) instance child feature: 4
# No (0) instance child feature: 14
#
# Root Node Feature: 8
# Root Node Feature: 15
# Yes (1) instance child feature: 14Yes (1) instance child feature: 4
# No (0) instance child feature: 13
# No (0) instance child feature: 10
#
#
# Yes (1) instance child feature: 13Yes (1) instance child feature: 10
#
# new depth of tree 6new depth of tree 6
#
#
# ----------------------------------------
# ----------------------------------------new depth of tree 6
#
# new depth of tree 6
# queue empty: False
# queue empty: False
#
#
#
#
# ----------------------------------------
# ----------------------------------------
# Working on node number 25 with depth 4
# Working on node number 25 with depth 4
#
#
#
# queue empty: False
#
# queue empty: False
#
# Subset features rows 11
# Working on node number 27 with depth 4Subset features rows 17
# Working on node number 29 with depth 4
#
#
#
# targets rows 11targets rows 17Subset features rows 21
#
# Subset features rows 11
#
# Preprocessing ...
# Preprocessing ...
#
# targets rows 21
#
# targets rows 11
# Preprocessing ...
#
# Finding features for subtree
# Finding features for subtree
#
# Preprocessing ...
#
#
#
# Finding features for subtree
#
# Finding features for subtree
#
# Selected features subtree:
# Selected features subtree:
#
# Root Node Feature: 1Root Node Feature: 10
#
# No (0) instance child feature: 4
# Selected features subtree:
# Selected features subtree:No (0) instance child feature: 6
#
#
#
# Yes (1) instance child feature: 4Root Node Feature: 2Root Node Feature: 8Yes (1) instance child feature: 6
#
#
#
# No (0) instance child feature: 14No (0) instance child feature: 5
#
# Yes (1) instance child feature: 12Yes (1) instance child feature: 5
# Distributing to children from pure node 51...
#
#
# new depth of tree 6
# new depth of tree 6
# ----------------------------------------
# Distributing to children from pure node 60...
#
#
#
# ----------------------------------------
# queue empty: False
#
# new depth of tree 6
# queue empty: Falsenew depth of tree 6
# Working on node number 26 with depth 4
#
#
#
#
# ----------------------------------------
# Working on node number 26 with depth 4
# ----------------------------------------
#
#
# queue empty: False
# Subset features rows 6
# queue empty: False
#
# Subset features rows 8
#
# Working on node number 30 with depth 4targets rows 6
#
# Working on node number 30 with depth 4
#
#
# targets rows 8
# Preprocessing ...
# Subset features rows 8
# Subset features rows 6
#
# Preprocessing ...
#
# targets rows 8
# Finding features for subtreetargets rows 6
#
#
#
# Preprocessing ...
# Finding features for subtree
# Preprocessing ...
#
#
#
# Finding features for subtree
# Finding features for subtree
#
#
# Selected features subtree:
#
# Selected features subtree:Root Node Feature: 11
#
# Root Node Feature: 2No (0) instance child feature: 5
#
#
# Selected features subtree:No (0) instance child feature: 5
# Selected features subtree:
# Yes (1) instance child feature: 5
#
#
# Root Node Feature: 5Yes (1) instance child feature: 7Root Node Feature: 3
#
# No (0) instance child feature: 3
#
# No (0) instance child feature: 11Yes (1) instance child feature: 3
# new depth of tree 6
# Yes (1) instance child feature: 11
#
#
# ----------------------------------------new depth of tree 6
#
#
# queue empty: False
# new depth of tree 6
# ----------------------------------------
# Distributing to children from pure node 62...
# Working on node number 27 with depth 4
#
#
#
#
# ----------------------------------------
# queue empty: False
#
#
# queue empty: Falsenew depth of tree 6Subset features rows 8
# Working on node number 27 with depth 4
#
#
#
#
# ----------------------------------------
# Working on node number 31 with depth 5targets rows 8
#
#
# Subset features rows 25
# queue empty: False
# Preprocessing ...
#
#
#
# Working on node number 31 with depth 5Subset features rows 25targets rows 25
#
#
#
# Finding features for subtree
# Preprocessing ...Subset features rows 46targets rows 25
#
#
#
#
# Preprocessing ...targets rows 46
#
# Finding features for subtree
#
#
# Preprocessing ...
# Finding features for subtree
#
#
# Finding features for subtree
# Selected features subtree:
#
# Root Node Feature: 4
# No (0) instance child feature: 8
# Selected features subtree:
#
# Yes (1) instance child feature: 6Root Node Feature: 3
#
#
# Selected features subtree:No (0) instance child feature: 6
#
# Root Node Feature: 9Yes (1) instance child feature: 15
#
#
# Selected features subtree:No (0) instance child feature: 15
#
# new depth of tree 6Root Node Feature: 12Yes (1) instance child feature: 11
#
#
# No (0) instance child feature: 11
# ----------------------------------------
#
#
# Distributing to children from pure node 56...Yes (1) instance child feature: 11
# queue empty: False
#
#
#
# Working on node number 31 with depth 5
# new depth of tree 6
# new depth of tree 7
# ----------------------------------------Subset features rows 29
#
#
#
# ----------------------------------------
# queue empty: False
# new depth of tree 7
# targets rows 29
# queue empty: False
#
# Working on node number 28 with depth 4
#
#
#
# ----------------------------------------
# Preprocessing ...
# Working on node number 32 with depth 5
#
#
# Subset features rows 8
# queue empty: False
#
# Subset features rows 20
# Working on node number 32 with depth 5
# Finding features for subtree
# targets rows 8
#
#
# targets rows 20Subset features rows 27
# Preprocessing ...
#
#
# Preprocessing ...
#
# targets rows 27
#
# Finding features for subtree
# Preprocessing ...
#
# Finding features for subtree
#
#
# Finding features for subtree
# Selected features subtree:
#
# Root Node Feature: 2
# No (0) instance child feature: 14
#
# Selected features subtree:Yes (1) instance child feature: 14
#
# Selected features subtree:
#
# Root Node Feature: 2Root Node Feature: 10
#
# No (0) instance child feature: 4No (0) instance child feature: 14
# Selected features subtree:
#
#
# Yes (1) instance child feature: 4Yes (1) instance child feature: 14Root Node Feature: 14
#
#
# No (0) instance child feature: 1new depth of tree 7
#
#
# Distributing to children from pure node 57...Yes (1) instance child feature: 1
# ----------------------------------------
#
#
#
# queue empty: False
# Distributing to children from pure node 66...
#
#
# Working on node number 32 with depth 5
# new depth of tree 6new depth of tree 7new depth of tree 7
#
# ----------------------------------------
# Subset features rows 7
#
#
# ----------------------------------------
#
# ----------------------------------------
# queue empty: False
#
#
# targets rows 7
# queue empty: False
# queue empty: False
# Working on node number 31 with depth 5
#
#
#
#
# Preprocessing ...
# Working on node number 33 with depth 5
# Working on node number 35 with depth 5
#
#
# Subset features rows 45
# Subset features rows 12Subset features rows 20
# Finding features for subtree
#
# targets rows 45
#
# targets rows 12targets rows 20
# Preprocessing ...
#
#
#
# Preprocessing ...
# Preprocessing ...
#
#
# Finding features for subtree
# Finding features for subtree
# Finding features for subtree
#
#
#
# Selected features subtree:
# Root Node Feature: 7
# No (0) instance child feature: 14
# Yes (1) instance child feature: 10
#
# Selected features subtree:
# Selected features subtree:
# Selected features subtree:
#
#
# Root Node Feature: 3Root Node Feature: 5Root Node Feature: 8
#
#
# No (0) instance child feature: 11No (0) instance child feature: 6No (0) instance child feature: 7
#
#
# new depth of tree 7Yes (1) instance child feature: 13Yes (1) instance child feature: 7Yes (1) instance child feature: 6
#
#
#
# ----------------------------------------
#
#
# queue empty: False
#
# Working on node number 33 with depth 5
# new depth of tree 7
# new depth of tree 7
# ----------------------------------------Subset features rows 21new depth of tree 7
#
#
#
#
# ----------------------------------------
# queue empty: False
# ----------------------------------------
#
# targets rows 21
#
# queue empty: False
# Working on node number 34 with depth 5
# queue empty: False
#
#
#
#
# Preprocessing ...
# Working on node number 32 with depth 5
#
# Working on node number 39 with depth 5Subset features rows 6
#
#
# Subset features rows 28targets rows 6Subset features rows 12
# Finding features for subtree
#
#
#
#
# Preprocessing ...targets rows 28targets rows 12
#
#
#
# Preprocessing ...
# Preprocessing ...
#
#
# Finding features for subtree
#
# Finding features for subtree
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 9
# No (0) instance child feature: 10
#
# Selected features subtree:Yes (1) instance child feature: 15
#
# Selected features subtree:
# Root Node Feature: 14
# Selected features subtree:
#
#
# Root Node Feature: 1No (0) instance child feature: 6Root Node Feature: 7
#
#
# No (0) instance child feature: 3Yes (1) instance child feature: 11No (0) instance child feature: 2
#
#
# new depth of tree 7Yes (1) instance child feature: 3
# Yes (1) instance child feature: 2
#
# ----------------------------------------
#
#
# queue empty: Falsenew depth of tree 7
#
#
# Working on node number 34 with depth 5
# ----------------------------------------new depth of tree 7
#
# new depth of tree 7
#
# queue empty: False
#
# ----------------------------------------
# Subset features rows 15
# ----------------------------------------
#
# Working on node number 35 with depth 5
#
#
# queue empty: False
#
# queue empty: False
# targets rows 15
#
# Working on node number 35 with depth 5
# Subset features rows 35
# Working on node number 40 with depth 5
#
#
# Preprocessing ...
#
# Subset features rows 55targets rows 35
#
# Subset features rows 11
# Finding features for subtree
# Preprocessing ...
# targets rows 55
#
#
# targets rows 11
# Preprocessing ...
#
#
# Finding features for subtree
# Preprocessing ...
#
#
# Finding features for subtree
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 12
#
# Selected features subtree:No (0) instance child feature: 3
#
# Root Node Feature: 10Yes (1) instance child feature: 3
# Selected features subtree:
# Selected features subtree:
#
#
#
# No (0) instance child feature: 2Root Node Feature: 2Root Node Feature: 10
#
#
# Yes (1) instance child feature: 2No (0) instance child feature: 9
# No (0) instance child feature: 13
#
# Distributing to children from pure node 70...
# Yes (1) instance child feature: 7
# Yes (1) instance child feature: 13
#
# new depth of tree 7
#
# ----------------------------------------new depth of tree 7
#
#
# queue empty: False
# ----------------------------------------
# new depth of tree 7new depth of tree 7
#
# Working on node number 35 with depth 5
#
#
# queue empty: False
#
# ----------------------------------------
# ----------------------------------------
#
#
#
# Working on node number 37 with depth 5
# queue empty: FalseSubset features rows 13
# queue empty: False
#
#
#
#
# Working on node number 43 with depth 5Subset features rows 28
# Working on node number 36 with depth 5
# targets rows 13
#
#
# Subset features rows 7targets rows 28Subset features rows 12
# Preprocessing ...
#
#
#
#
# Preprocessing ...targets rows 12targets rows 7
#
#
#
# Preprocessing ...
# Finding features for subtree
# Preprocessing ...
#
# Finding features for subtree
#
#
# Finding features for subtree
# Finding features for subtree
#
#
#
# Selected features subtree:
#
# Selected features subtree:
# Selected features subtree:
#
#
# Selected features subtree:Root Node Feature: 1Root Node Feature: 9
#
# No (0) instance child feature: 2Root Node Feature: 3
# No (0) instance child feature: 10
# Root Node Feature: 2
# Yes (1) instance child feature: 2
# Yes (1) instance child feature: 12
# No (0) instance child feature: 8
#
#
# No (0) instance child feature: 15
# new depth of tree 7Yes (1) instance child feature: 13
# Distributing to children from pure node 72...
# Yes (1) instance child feature: 8
#
# ----------------------------------------
#
#
#
# queue empty: Falsenew depth of tree 7
# new depth of tree 7
#
# Distributing to children from pure node 74...
#
# ----------------------------------------
#
#
# Working on node number 46 with depth 5
# ----------------------------------------
# queue empty: False
#
# new depth of tree 7
#
#
# queue empty: False
# Working on node number 36 with depth 5Subset features rows 4
# ----------------------------------------
#
#
#
#
# Working on node number 38 with depth 5
# queue empty: FalseSubset features rows 24
# targets rows 4
#
#
#
# Working on node number 37 with depth 5targets rows 24Subset features rows 14
# Preprocessing ...
#
#
#
#
# Preprocessing ...Subset features rows 21
# targets rows 14
#
#
# Finding features for subtree
# Preprocessing ...targets rows 21
# Finding features for subtree
#
#
#
#
# Preprocessing ...
#
# Finding features for subtree
# Finding features for subtree
#
#
# Selected features subtree:
# Selected features subtree:
# Root Node Feature: 1
# Root Node Feature: 11
#
#
# Selected features subtree:No (0) instance child feature: 3
#
# No (0) instance child feature: 3Root Node Feature: 3Yes (1) instance child feature: 3
#
# Selected features subtree:
#
# Yes (1) instance child feature: 3
# No (0) instance child feature: 2
# Root Node Feature: 6
#
# Yes (1) instance child feature: 4No (0) instance child feature: 12
#
# new depth of tree 7Yes (1) instance child feature: 8
#
#
# ----------------------------------------new depth of tree 7
# Distributing to children from pure node 78...
#
#
#
# queue empty: False
# ----------------------------------------
#
#
# Working on node number 51 with depth 5
# queue empty: Falsenew depth of tree 7new depth of tree 7
#
#
#
# Working on node number 37 with depth 5
#
# ----------------------------------------
# Subset features rows 34
# ----------------------------------------
#
#
# Subset features rows 10
# queue empty: Falsetargets rows 34
#
#
#
# queue empty: False
# Preprocessing ...
# Working on node number 39 with depth 5targets rows 10
#
#
# Working on node number 41 with depth 5
#
#
# Preprocessing ...
#
# Subset features rows 16
# Finding features for subtreeSubset features rows 13
#
#
#
# Finding features for subtreetargets rows 13targets rows 16
#
#
#
# Preprocessing ...
# Preprocessing ...
# Selected features subtree:
#
#
# Root Node Feature: 8
# Finding features for subtree
# Finding features for subtree
#
#
# No (0) instance child feature: 11
#
# Selected features subtree:Yes (1) instance child feature: 14
#
# Root Node Feature: 8
# No (0) instance child feature: 5
# Selected features subtree:
#
# Selected features subtree:new depth of tree 7Yes (1) instance child feature: 5
#
#
# Root Node Feature: 3
#
# ----------------------------------------Root Node Feature: 8
#
#
# No (0) instance child feature: 10
# queue empty: FalseNo (0) instance child feature: 9
#
#
# Yes (1) instance child feature: 10Yes (1) instance child feature: 9
#
# Working on node number 52 with depth 5
# new depth of tree 7
#
#
# ----------------------------------------Subset features rows 39
#
#
# queue empty: False
# Distributing to children from pure node 84...
#
# targets rows 39new depth of tree 7
# Working on node number 38 with depth 5
#
#
#
# Preprocessing ...
# ----------------------------------------
# new depth of tree 7Subset features rows 10
#
#
#
# queue empty: False
# ----------------------------------------
#
# Finding features for subtree
#
# Working on node number 40 with depth 5targets rows 10
# queue empty: False
#
#
#
#
# Preprocessing ...
# Working on node number 43 with depth 5
# Subset features rows 16
#
# Subset features rows 7targets rows 16
# Finding features for subtree
#
#
#
# Preprocessing ...targets rows 7
#
#
# Preprocessing ...
#
# Selected features subtree:
# Finding features for subtree
#
# Root Node Feature: 6
# Finding features for subtree
#
# No (0) instance child feature: 12
#
# Selected features subtree:Yes (1) instance child feature: 12
#
# Root Node Feature: 4
# No (0) instance child feature: 1
#
# Selected features subtree:Yes (1) instance child feature: 1
#
# Root Node Feature: 1
# Selected features subtree:
#
# No (0) instance child feature: 9new depth of tree 7Root Node Feature: 11
#
#
# Yes (1) instance child feature: 9No (0) instance child feature: 5
# ----------------------------------------
#
# new depth of tree 7
# Yes (1) instance child feature: 5
#
# queue empty: False
#
# ----------------------------------------
#
#
# Working on node number 53 with depth 5
# queue empty: False
#
#
# Working on node number 39 with depth 5
# Subset features rows 41
# Distributing to children from pure node 88...new depth of tree 7
#
#
# Subset features rows 22
# ----------------------------------------
# targets rows 41
#
# targets rows 22new depth of tree 7
# queue empty: False
# Preprocessing ...
#
#
#
# Preprocessing ...
# ----------------------------------------
#
# Working on node number 41 with depth 5
#
#
#
# queue empty: False
#
# Finding features for subtreeSubset features rows 4
# Finding features for subtree
# Working on node number 44 with depth 5
#
#
#
# targets rows 4Subset features rows 9
#
#
# Selected features subtree:
# Selected features subtree:
# targets rows 9
# Preprocessing ...Root Node Feature: 5
#
#
# Preprocessing ...
#
#
# No (0) instance child feature: 14Root Node Feature: 7
#
# No (0) instance child feature: 3
# Finding features for subtreeYes (1) instance child feature: 3
#
# Finding features for subtree
# Yes (1) instance child feature: 3
#
#
# new depth of tree 7
#
# ----------------------------------------new depth of tree 7
#
# Selected features subtree:
# queue empty: False
#
# Root Node Feature: 11
#
# Selected features subtree:
#
# ----------------------------------------
# Working on node number 40 with depth 5
# Root Node Feature: 10
#
#
# No (0) instance child feature: 15
# queue empty: FalseNo (0) instance child feature: 11Subset features rows 16
#
#
# Yes (1) instance child feature: 7
#
# Working on node number 55 with depth 5
# targets rows 16Yes (1) instance child feature: 11
#
# Distributing to children from pure node 83...
#
# Subset features rows 16
#
# Preprocessing ...
# targets rows 16new depth of tree 7
#
#
#
# Preprocessing ...new depth of tree 7
#
# ----------------------------------------
# Finding features for subtree
#
#
#
# queue empty: False
# ----------------------------------------
# Finding features for subtree
#
#
#
# queue empty: False
# Working on node number 42 with depth 5
#
# Working on node number 45 with depth 5
#
# Subset features rows 4Subset features rows 5
#
# targets rows 5
# Selected features subtree:targets rows 4
# Selected features subtree:
#
#
#
#
# Preprocessing ...Root Node Feature: 3
# Preprocessing ...Root Node Feature: 1
#
#
#
# No (0) instance child feature: 15No (0) instance child feature: 2
# Finding features for subtree
# Finding features for subtree
#
#
#
# Yes (1) instance child feature: 2Yes (1) instance child feature: 15
#
#
# Distributing to children from pure node 111...
# Distributing to children from pure node 81...
# Selected features subtree:
# Selected features subtree:
#
#
#
# Root Node Feature: 12Root Node Feature: 15
#
# No (0) instance child feature: 12No (0) instance child feature: 11new depth of tree 7
#
# new depth of tree 7
# Yes (1) instance child feature: 12
# Yes (1) instance child feature: 4
# ----------------------------------------
#
# ----------------------------------------
#
#
#
# queue empty: False
# queue empty: False
#
#
# Working on node number 41 with depth 5
# Working on node number 56 with depth 5
#
# new depth of tree 7new depth of tree 7
#
# Subset features rows 23Subset features rows 2
# ----------------------------------------
# ----------------------------------------
#
#
#
#
# queue empty: False
# queue empty: Falsetargets rows 23targets rows 2
#
#
#
#
# Working on node number 44 with depth 5
# Preprocessing ...
# Preprocessing ...
# Working on node number 46 with depth 5
#
#
#
# Subset features rows 9Subset features rows 6
#
# Finding features for subtree
# Finding features for subtree
#
#
# targets rows 9targets rows 6
#
# Preprocessing ...
#
#
# Preprocessing ...
#
# Finding features for subtree
# Finding features for subtree
#
#
# Selected features subtree:
# Selected features subtree:
#
# ...
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 0 with depth 0
# Subset features rows 301
# targets rows 301
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 13
# No (0) instance child feature: 4
# Yes (1) instance child feature: 8
# new depth of tree 2
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 1 with depth 1
# Subset features rows 232
# targets rows 232
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 4
# No (0) instance child feature: 11
# Yes (1) instance child feature: 6
# new depth of tree 3
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 2 with depth 1
# Subset features rows 69
# targets rows 69
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 5
# No (0) instance child feature: 8
# Yes (1) instance child feature: 8
# new depth of tree 3
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 3 with depth 2
# Subset features rows 152
# targets rows 152
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 8
# No (0) instance child feature: 14
# Yes (1) instance child feature: 7
# new depth of tree 4
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 4 with depth 2
# Subset features rows 80
# targets rows 80
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 6
# No (0) instance child feature: 14
# Yes (1) instance child feature: 11
# new depth of tree 4
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 5 with depth 2
# Subset features rows 48
# targets rows 48
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 9
# No (0) instance child feature: 1
# Yes (1) instance child feature: 11
# new depth of tree 4
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 6 with depth 2
# Subset features rows 21
# targets rows 21
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 11
# No (0) instance child feature: 5
# Yes (1) instance child feature: 5
# new depth of tree 4
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 7 with depth 3
# Subset features rows 101
# targets rows 101
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 11
# No (0) instance child feature: 7
# Yes (1) instance child feature: 7
# new depth of tree 5
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 8 with depth 3
# Subset features rows 51
# targets rows 51
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 7
# No (0) instance child feature: 3
# Yes (1) instance child feature: 3
# new depth of tree 5
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 9 with depth 3
# Subset features rows 53
# targets rows 53
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 12
# No (0) instance child feature: 2
# Yes (1) instance child feature: 2
# new depth of tree 5
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 10 with depth 3
# Subset features rows 27
# targets rows 27
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 14
# No (0) instance child feature: 1
# Yes (1) instance child feature: 1
# new depth of tree 5
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 11 with depth 3
# Subset features rows 33
# targets rows 33
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 1
# No (0) instance child feature: 7
# Yes (1) instance child feature: 7
# new depth of tree 5
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 12 with depth 3
# Subset features rows 15
# targets rows 15
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 12
# No (0) instance child feature: 5
# Yes (1) instance child feature: 8
# new depth of tree 5
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 13 with depth 3
# Subset features rows 13
# targets rows 13
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 7
# No (0) instance child feature: 9
# Yes (1) instance child feature: 6
# new depth of tree 5
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 14 with depth 3
# Subset features rows 8
# targets rows 8
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 14
# No (0) instance child feature: 3
# Yes (1) instance child feature: 3
# new depth of tree 5
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 15 with depth 4
# Subset features rows 71
# targets rows 71
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 2
# No (0) instance child feature: 15
# Yes (1) instance child feature: 10
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 16 with depth 4
# Subset features rows 30
# targets rows 30
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 1
# No (0) instance child feature: 12
# Yes (1) instance child feature: 2
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 17 with depth 4
# Subset features rows 51
# targets rows 51
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 13
# No (0) instance child feature: 4
# Yes (1) instance child feature: 4
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 19 with depth 4
# Subset features rows 40
# targets rows 40
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 11
# No (0) instance child feature: 15
# Yes (1) instance child feature: 15
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 20 with depth 4
# Subset features rows 13
# targets rows 13
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 15
# No (0) instance child feature: 12
# Yes (1) instance child feature: 12
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 21 with depth 4
# Subset features rows 19
# targets rows 19
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 13
# No (0) instance child feature: 5
# Yes (1) instance child feature: 5
# new depth of tree 6
#
# ----------------------------------------
#
# queue empty: False
#
# Working on node number 22 with depth 4
# Subset features rows 8
# targets rows 8
#
# Preprocessing ...
#
# Finding features for subtree
#
# Selected features subtree:
# Root Node Feature: 14
# No (0) instance child feature: 11
# Process ForkPoolWorker-31:
# Process ForkPoolWorker-30:
# Process ForkPoolWorker-29:
# Process ForkPoolWorker-32:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.12/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/usr/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/tmp/ipykernel_368913/582567122.py", line 34, in fit_single_tree
#     tree.fit(X_boot, y_boot)
#   File "/usr/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#   File "/usr/lib/python3.12/multiprocessing/queues.py", line 387, in get
#     res = self._reader.recv_bytes()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 forest.fit(features_train, targets_train)
#
# Cell In[41], line 60, in CustomForestClassifier.fit(self, X, y)
#      57 random_states = [self.random_state + i for i in range(self.n_estimators)] if self.random_state is not None else [None]*self.n_estimators
#      58 args = [(X, y, self.max_depth,self.max_features , rs) for rs in random_states]
# ---> 60 results = pool.map(fit_single_tree, args)
#      61 pool.close()
#      62 pool.join()
#
# File /usr/lib/python3.12/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File /usr/lib/python3.12/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File /usr/lib/python3.12/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File /usr/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /usr/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:
#   File "/usr/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#   File "/usr/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py", line 136, in fit
#     print(f"No (0) instance child feature: {node1_feature}")
#   File "/home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3045, in write
#     result = original_write(data, *args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/ipykernel/iostream.py", line 692, in write
#     self.pub_thread.schedule(self._flush)
#   File "/home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/ipykernel/iostream.py", line 269, in schedule
#     f()
#   File "/home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/ipykernel/iostream.py", line 649, in _flush
#     self.session.send(
#   File "/home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 852, in send
#     to_send = self.serialize(msg, ident)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 733, in serialize
#     self.pack(msg["parent_header"]),
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/.venv/lib/python3.12/site-packages/jupyter_client/session.py", line 95, in json_packer
#     return json.dumps(
#            ^^^^^^^^^^^
#   File "/usr/lib/python3.12/json/__init__.py", line 238, in dumps
#     **kw).encode(obj)
#           ^^^^^^^^^^^
#   File "/usr/lib/python3.12/json/encoder.py", line 200, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/json/encoder.py", line 258, in iterencode
#     return _iterencode(o, 0)
#            ^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Process ForkPoolWorker-39:
# Process ForkPoolWorker-37:
# Process ForkPoolWorker-34:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/usr/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/usr/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/usr/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#   File "/usr/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#   File "/usr/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#   File "/usr/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/usr/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt

# %%
r_test = forest.predict(features_test)
#r_test = r_test.astype(int)
result_test = pd.DataFrame({
    'y': targets_test,
    'prediction': r_test
})

#print(result_test)
# Out:
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None
# /home/drood/Obsidian/Files/Bachelorarbeit/rlrf_my_try/rolling_lookahead_dt_restructured/tree_refactored/class_tree.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['prediction'] = None

# %%
from sklearn.metrics import matthews_corrcoef

mcc_test = matthews_corrcoef(result_test['y'], result_test['prediction'])
print(mcc_test)
# Out:
# 0.016673963600541856
